# %%
#IMPORT NECESSARY LIBRARIES

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
import time
import gurobipy as gp
from gurobipy import GRB
import networkx as nx

# %%
# filepath = "C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files/Delorme_1000_NDD_Unit_0.txt"

# %%
def import_kidney_data(filepath):
    """
    Imports kidney exchange data from a text file and structures it into a dictionary.

    Args:
        filepath (str): The path to the text file containing the kidney exchange data.

    Returns:
        dict: A dictionary containing the following keys:
            - num_pairs (int): The number of pairs (donor-patient pairs) in the instance.
            - num_ndd (int): The number of non-directed donors (NDDs) in the instance.
            - num_arcs (int): The total number of arcs in the instance.
            - pairs (list): A list of dictionaries, each representing a pair or NDD with the following keys:
                - id (int): The unique ID of the pair.
                - is_ndd (bool): True if the pair is an NDD, False otherwise.
                - donor_blood_type (int): Donor's blood type (0 = A, 1 = B, 2 = AB, 3 = O).
                - patient_blood_type (int): Patient's blood type (0 = A, 1 = B, 2 = AB, 3 = O).
                - patient_vpra (int): Patient's vPRA score (0 = below 0.5, 1 = between 0.5 and 0.85, 2 = above 0.85).
            - arcs (list): A list of dictionaries representing the arcs between pairs with the following keys:
                - donor_id (int): ID of the donor pair.
                - patient_id (int): ID of the patient pair.
                - weight (int): The weight of the arc (always 1 in this case).

    Example:
        data = import_kidney_data('path/to/data.txt')
        print(data['num_pairs'])  # Output: Number of pairs in the instance
    """

    data = {}
    
    # Open the file and read all lines into memory
    with open(filepath, 'r') as f:
        lines = f.readlines()
        
        # Parse metadata: number of pairs, NDDs, and arcs
        num_pairs = int(lines[0].split(' ')[2])
        num_ndd = int(lines[1].split(' ')[2])
        num_arcs = int(lines[2].split(' ')[2])
        
        # Store the parsed values in the data dictionary
        data['num_pairs'] = num_pairs
        data['num_ndd'] = num_ndd
        data['num_arcs'] = num_arcs
        
        # Total number of entities (pairs + NDDs)
        num_things = num_pairs + num_ndd
        
        # List to store information about pairs and NDDs
        pairs = []
        
        # Parse each line corresponding to pairs and NDDs
        for line in lines[3:num_things + 3]:
            id, is_ndd, donor_blood_type, patient_blood_type, patient_vpra = map(int, line.strip().split(','))
            
            # Add pair/NDD info to the list
            pairs.append({
                'id': id,
                'is_ndd': bool(is_ndd),
                'donor_blood_type': donor_blood_type,
                'patient_blood_type': patient_blood_type,
                'patient_vpra': patient_vpra,
            })
        
        # Store the pairs data in the dictionary
        data['pairs'] = pairs

        # List to store information about arcs
        arcs = []
        
        # Parse each line corresponding to arcs (donor-patient relationships)
        for line in lines[num_things + 3:]:
            arc, weight = line.strip().split(',1,')
            
            # Extract donor and patient IDs from the arc
            donor_id, patient_id = arc.split(',')
            weight = int(weight.strip())  # Weight is always 1 in this context
            donor_id = int(donor_id[1:])  # Remove prefix and convert to int
            patient_id = int(patient_id[:-1])  # Remove suffix and convert to int
            
            # Add arc info to the list
            arcs.append({
                'donor_id': donor_id,
                'patient_id': patient_id,
                'weight': weight,
            })
        
        # Store the arcs data in the dictionary
        data['arcs'] = arcs

    # Return the final structured dictionary
    return data


# Example usage of the function
#data = import_kidney_data(filepath)

# %%
def create_graph(data):
    """
    Creates a directed graph from the input data.

    Parameters:
    data (dict): A dictionary with two keys:
        - 'pairs': A list of dictionaries, each containing an 'id' for a node.
        - 'arcs': A list of dictionaries, each containing 'donor_id' (start node), 
                  'patient_id' (end node), and 'weight' (weight of the edge).

    Returns:
    G (nx.DiGraph): A directed graph created from the input data.
    """
    G = nx.DiGraph()
    
    # Add nodes to the graph from 'pairs' in data
    for pair in data['pairs']:
        G.add_node(pair['id'])
    
    # Add edges (directed) with weights from 'arcs' in data
    for arc in data['arcs']:
        G.add_edge(arc['donor_id'], arc['patient_id'], weight=arc['weight'])
    
    return G


def findPaths(G, u, n):
    """
    Recursively finds all paths of length n starting from node u.

    Parameters:
    G (nx.DiGraph): A directed graph.
    u (hashable): The starting node of the path.
    n (int): The length of the paths to find.

    Returns:
    paths (list): A list of all possible paths of length n starting from node u. 
                  Each path is represented as a list of nodes.
    """
    if n == 0:
        # Base case: if the path length is 0, return the starting node as the path
        return [[u]]
    
    # Recursive case: explore neighbors of the current node and find paths of length n-1
    paths = [[u] + path for neighbor in G.neighbors(u) for path in findPaths(G, neighbor, n-1)]
    
    return paths


def find_cycles(G, u, n):
    """
    Finds all cycles of length n starting and ending at node u.

    Parameters:
    G (nx.DiGraph): A directed graph.
    u (hashable): The node where the cycle starts and ends.
    n (int): The length of the cycle (number of edges in the cycle).

    Returns:
    cycles (list): A list of all cycles of length n starting and ending at node u.
                   Each cycle is represented as a tuple of nodes.
    """
    # Find all paths of length n starting from node u
    paths = findPaths(G, u, n)
    
    # Filter paths that form a cycle, meaning they end at u and visit u exactly twice
    return [tuple(path) for path in paths if (path[-1] == u) and sum(x == u for x in path) == 2]


def set_weight(dict_list, donor_id, patient_id, weight_key="weight"):
    """
    Retrieve the weight of an arc between a donor and a patient.

    Args:
        dict_list (list): List of dictionaries representing arcs.
        donor_id (int): The ID of the donor.
        patient_id (int): The ID of the patient.
        weight_key (str): The key to access the weight in the dictionary (default is "weight").

    Returns:
        int: The weight of the arc if found, otherwise None.
    """
    for dct in dict_list:
        if dct.get("donor_id") == donor_id and dct.get("patient_id") == patient_id:
            return dct.get(weight_key)
    return None  # Return None if no matching arc is found

# %%
# G = create_graph(data)  # Create a directed graph from the data

# %%
# k = 3  # Maximum length for cycles and paths -> 2-cycle 
# c = []  # List to store information about cycles
# p = []  # List to store information about paths

# id_count = 0
# # Loop through possible cycle lengths from 1 to k-1
# for l in range(1, k):
#     for node in G.nodes:  # Iterate over all nodes in the graph
#         for cyc in list(find_cycles(G, node, l)):  # Find all cycles starting at this node of length 'l'
#             cyc_success = 0
#             cyc_weight = 0
#             # Calculate the success and weight for the cycle
#             for n in range(1, len(cyc)):
#                 cyc_success += data['pairs'][cyc[n]]['patient_vpra']  # Sum up the vPRA values of patients in the cycle
#                 cyc_weight += set_weight(data['arcs'], cyc[n-1], cyc[n])  # Add the weight of the arc between consecutive pairs in the cycle
#             # Append the cycle info to the list 'c'
#             c.append({'id': id_count,'cycle': cyc, 'vpra_sum': cyc_success, 'weight_sum': cyc_weight})  
#             id_count += 1


# # Loop through possible path lengths from 1 to k-2 (since paths are from NDDs)
# for l in range(1, k-1):
#     for node in G.nodes:  # Iterate over all nodes in the graph
#         if data['pairs'][node]['is_ndd']:  # Only consider nodes that are NDDs
#             for path in list(findPaths(G, node, l)):  # Find all paths starting at this NDD node of length 'l'
#                 path_success = 0
#                 path_weight = 0
#                 # Calculate the success and weight for the path
#                 for n in range(1, len(path)):
#                     path_success += data['pairs'][path[n]]['patient_vpra']  # Sum up the vPRA values of patients in the path
#                     path_weight += set_weight(data['arcs'], path[n-1], path[n])  # Add the weight of the arc between consecutive pairs in the path
#                 # Append the path info to the list 'p'
#                 p.append({'id':id_count,'path': path, 'vpra_sum': path_success, 'weight_sum': path_weight}) 
#                 id_count += 1

# # Print the results
# print("Cycles:", c)
# print("Paths:", p)

# %%
def calculate_cycles_and_paths(G, data, k=3):
    """
    Calculates cycles and paths from the directed graph G.
    
    Parameters:
    G (nx.DiGraph): The directed graph.
    data (dict): The kidney exchange data.
    k (int): The maximum cycle length (default is 3).
    
    Returns:
    c (list): A list of cycles.
    p (list): A list of paths.
    """
    c = []  # List to store information about cycles
    p = []  # List to store information about paths
    id_count = 0

    # Loop through possible cycle lengths from 1 to k-1
    for l in range(1, k):
        for node in G.nodes:  # Iterate over all nodes in the graph
            for cyc in list(find_cycles(G, node, l)):  # Find all cycles starting at this node of length 'l'
                cyc_success = 0
                cyc_weight = 0
                # Calculate the success and weight for the cycle
                for n in range(1, len(cyc)):
                    cyc_success += data['pairs'][cyc[n]]['patient_vpra']  # Sum up the vPRA values of patients in the cycle
                    cyc_weight += set_weight(data['arcs'], cyc[n-1], cyc[n])  # Add the weight of the arc between consecutive pairs in the cycle
                # Append the cycle info to the list 'c'
                c.append({'id': id_count,'cycle': cyc, 'vpra_sum': cyc_success, 'weight_sum': cyc_weight})  
                id_count += 1

    # Loop through possible path lengths from 1 to k-2 (since paths are from NDDs)
    for l in range(1, k-1):
        for node in G.nodes:  # Iterate over all nodes in the graph
            if data['pairs'][node]['is_ndd']:  # Only consider nodes that are NDDs
                for path in list(findPaths(G, node, l)):  # Find all paths starting at this NDD node of length 'l'
                    path_success = 0
                    path_weight = 0
                    # Calculate the success and weight for the path
                    for n in range(1, len(path)):
                        path_success += data['pairs'][path[n]]['patient_vpra']  # Sum up the vPRA values of patients in the path
                        path_weight += set_weight(data['arcs'], path[n-1], path[n])  # Add the weight of the arc between consecutive pairs in the path
                    # Append the path info to the list 'p'
                    p.append({'id':id_count,'path': path, 'vpra_sum': path_success, 'weight_sum': path_weight}) 
                    id_count += 1
    
    # Return cycles and paths
    return c, p

# %% [markdown]
# # Implement branch and cut method

# %%
def solve_kidney_exchange(G, cycles, paths, time_limit=300, mip_gap=0.01):
    """
    Solves the kidney exchange problem using Gurobi's branch-and-bound algorithm.

    Parameters:
    G (nx.DiGraph): A directed graph representing the kidney exchange network.
    cycles (list of dicts): List of cycles, where each dict contains:
        - 'id': Unique ID for the cycle.
        - 'cycle': List of nodes in the cycle.
        - 'weight_sum': Sum of weights (or values) for the edges in the cycle.
    paths (list of dicts): List of paths (chains from NDD), where each dict contains:
        - 'id': Unique ID for the path.
        - 'path': List of nodes in the path.
        - 'weight_sum': Sum of weights (or values) for the edges in the path.
    time_limit (int): The time limit for solving the model (in seconds).
    mip_gap (float): The MIP optimality gap tolerance.

    Returns:
    dict: A summary of the solution, including selected cycles, paths, and optimization statistics.
    """

    # Start timer for performance tracking
    start_time = time.time()

    # Initialize the model
    model = gp.Model("KidneyExchange")

    # Step 1: Define Binary decision variables for cycles and paths
    cycle_vars = {cycle['id']: model.addVar(vtype=GRB.BINARY, name=f"cycle_{cycle['id']}") for cycle in cycles}
    path_vars = {path['id']: model.addVar(vtype=GRB.BINARY, name=f"path_{path['id']}") for path in paths}

    # Step 2: Set objective function to maximize total weight of selected cycles and paths
    obj = gp.LinExpr()

    for cycle in cycles:
        obj += cycle['weight_sum'] * cycle_vars[cycle['id']]
    
    for path in paths:
        obj += path['weight_sum'] * path_vars[path['id']]

    model.setObjective(obj, GRB.MAXIMIZE)

    # Step 3: Add constraints to ensure each vertex (pair or NDD) is in at most one cycle or path
    for node in G.nodes:
        constraint = gp.LinExpr()

        # Add constraints for cycles
        for cycle in cycles:
            if node in cycle['cycle']:
                constraint += cycle_vars[cycle['id']]

        # Add constraints for paths
        for path in paths:
            if node in path['path']:
                constraint += path_vars[path['id']]

        # Ensure each node is used at most once
        model.addConstr(constraint <= 1, name=f"vertex_disjoint_{node}")

    # Step 4: Set solver parameters
    model.Params.TimeLimit = time_limit  # Set a time limit (in seconds)
    model.Params.MIPGap = mip_gap       # Set a MIP optimality gap tolerance

    # Solve the model
    model.optimize()

    # Initialize solution dictionary
    solution = {
        'total_score': 0,
        'selected_cycles': [],
        'selected_paths': [],
        'optimization_info': {}
    }

    # If the model is solved to optimality, collect the results
    if model.status == GRB.OPTIMAL:
        print("Optimal solution found!")
        total_score = 0
        solution_id = 1

        # Extract selected cycles
        for cycle in cycles:
            if cycle_vars[cycle['id']].x > 0.5:  # Cycle selected
                cycle_type = "Cycle"
                cycle_size = len(cycle['cycle'])  # Size of the cycle (number of nodes)
                cycle_nodes = ', '.join(map(str, cycle['cycle']))  # Nodes in the cycle
                cycle_score = cycle['weight_sum']  # Total score for the cycle
                total_score += cycle_score

                # Store cycle details in the solution
                solution['selected_cycles'].append({
                    'type': cycle_type,
                    'size': cycle_size,
                    'nodes': cycle_nodes,
                    'score': cycle_score
                })

        # Extract selected paths (chains)
        for path in paths:
            if path_vars[path['id']].x > 0.5:  # Path selected
                path_type = "Chain"
                path_size = len(path['path'])  # Size of the path (number of nodes)
                path_nodes = ', '.join(map(str, path['path']))  # Nodes in the path
                path_score = path['weight_sum']  # Total score for the path
                total_score += path_score

                # Store path details in the solution
                solution['selected_paths'].append({
                    'type': path_type,
                    'size': path_size,
                    'nodes': path_nodes,
                    'score': path_score
                })

        solution['total_score'] = total_score

        # Capture optimization statistics
        total_time = time.time() - start_time
        solution['optimization_info'] = {
            'optimal_solution_found': model.status == GRB.OPTIMAL,
            'total_time_s': total_time,
            'number_of_variables': model.NumVars,
            'number_of_constraints': model.NumConstrs,
            'number_of_non_zeros': model.NumNZs,
            'objective_1_max_cycles_and_chains': len(solution['selected_cycles']) + len(solution['selected_paths']),
            'objective_2_min_cycles_and_chains_of_size_4': len([x for x in solution['selected_cycles'] if len(x['nodes']) == 4]),
            'objective_3_min_cycles_chains_of_size_3': len([x for x in solution['selected_cycles'] if len(x['nodes']) == 3]),
            'objective_4_max_total_score_weight': total_score
        }
    else:
        print(f"No optimal solution found. Status: {model.status}")

    return solution

# Solve the kidney exchange problem using the branch-and-price algorithm

#solution = solve_kidney_exchange(G, c, p)

# print("Selected Cycles:")
# for idx, cycle in enumerate(solution['selected_cycles']):
#     print(f"{idx + 1}:")
#     print(f"Type: {cycle['type']}")
#     print(f"Size: {cycle['size']}")
#     print(f"Nodes: {cycle['nodes']}")
#     print(f"Score: {cycle['score']}")
#     print("-------------------------------------------")

# # Print the selected paths
# print("Selected Paths:")
# for idx, path in enumerate(solution['selected_paths']):
#     print(f"{idx + 1}:")
#     print(f"Type: {path['type']}")
#     print(f"Size: {path['size']}")
#     print(f"Nodes: {path['nodes']}")
#     print(f"Score: {path['score']}")
#     print("-------------------------------------------")

# # Print the total score
# print(f"Total score: {solution['total_score']}")

# # Print optimization information
# print("\nOptimization information:")
# for key, value in solution['optimization_info'].items():
#     print(f"{key}: {value}")
# Out:
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 2444 columns and 4888 nonzeros
# Model fingerprint: 0xdfa7cc8b
# Variable types: 0 continuous, 2444 integer (2444 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 190.0000000
# Presolve removed 959 rows and 2224 columns
# Presolve time: 0.01s
# Presolved: 41 rows, 220 columns, 440 nonzeros
# Found heuristic solution: objective 206.0000000
# Variable types: 0 continuous, 220 integer (220 binary)
#
# Root relaxation: cutoff, 67 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       206.00000  206.00000  0.00%     -    0s
#
# Explored 1 nodes (67 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 206 190
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 2.060000000000e+02, best bound 2.060000000000e+02, gap 0.0000%
# Optimal solution found!
# Selected Cycles:
# 1:
# Type: Cycle
# Size: 3
# Nodes: 4, 304, 4
# Score: 2
# -------------------------------------------
# 2:
# Type: Cycle
# Size: 3
# Nodes: 11, 445, 11
# Score: 2
# -------------------------------------------
# 3:
# Type: Cycle
# Size: 3
# Nodes: 12, 697, 12
# Score: 2
# -------------------------------------------
# 4:
# Type: Cycle
# Size: 3
# Nodes: 13, 175, 13
# Score: 2
# -------------------------------------------
# 5:
# Type: Cycle
# Size: 3
# Nodes: 15, 91, 15
# Score: 2
# -------------------------------------------
# 6:
# Type: Cycle
# Size: 3
# Nodes: 22, 131, 22
# Score: 2
# -------------------------------------------
# 7:
# Type: Cycle
# Size: 3
# Nodes: 28, 738, 28
# Score: 2
# -------------------------------------------
# 8:
# Type: Cycle
# Size: 3
# Nodes: 37, 328, 37
# Score: 2
# -------------------------------------------
# 9:
# Type: Cycle
# Size: 3
# Nodes: 43, 683, 43
# Score: 2
# -------------------------------------------
# 10:
# Type: Cycle
# Size: 3
# Nodes: 58, 94, 58
# Score: 2
# -------------------------------------------
# 11:
# Type: Cycle
# Size: 3
# Nodes: 66, 659, 66
# Score: 2
# -------------------------------------------
# 12:
# Type: Cycle
# Size: 3
# Nodes: 71, 245, 71
# Score: 2
# -------------------------------------------
# 13:
# Type: Cycle
# Size: 3
# Nodes: 78, 432, 78
# Score: 2
# -------------------------------------------
# 14:
# Type: Cycle
# Size: 3
# Nodes: 81, 939, 81
# Score: 2
# -------------------------------------------
# 15:
# Type: Cycle
# Size: 3
# Nodes: 82, 813, 82
# Score: 2
# -------------------------------------------
# 16:
# Type: Cycle
# Size: 3
# Nodes: 92, 120, 92
# Score: 2
# -------------------------------------------
# 17:
# Type: Cycle
# Size: 3
# Nodes: 99, 63, 99
# Score: 2
# -------------------------------------------
# 18:
# Type: Cycle
# Size: 3
# Nodes: 100, 563, 100
# Score: 2
# -------------------------------------------
# 19:
# Type: Cycle
# Size: 3
# Nodes: 106, 788, 106
# Score: 2
# -------------------------------------------
# 20:
# Type: Cycle
# Size: 3
# Nodes: 124, 819, 124
# Score: 2
# -------------------------------------------
# 21:
# Type: Cycle
# Size: 3
# Nodes: 128, 781, 128
# Score: 2
# -------------------------------------------
# 22:
# Type: Cycle
# Size: 3
# Nodes: 130, 585, 130
# Score: 2
# -------------------------------------------
# 23:
# Type: Cycle
# Size: 3
# Nodes: 138, 353, 138
# Score: 2
# -------------------------------------------
# 24:
# Type: Cycle
# Size: 3
# Nodes: 145, 799, 145
# Score: 2
# -------------------------------------------
# 25:
# Type: Cycle
# Size: 3
# Nodes: 184, 567, 184
# Score: 2
# -------------------------------------------
# 26:
# Type: Cycle
# Size: 3
# Nodes: 185, 804, 185
# Score: 2
# -------------------------------------------
# 27:
# Type: Cycle
# Size: 3
# Nodes: 189, 693, 189
# Score: 2
# -------------------------------------------
# 28:
# Type: Cycle
# Size: 3
# Nodes: 190, 208, 190
# Score: 2
# -------------------------------------------
# 29:
# Type: Cycle
# Size: 3
# Nodes: 193, 568, 193
# Score: 2
# -------------------------------------------
# 30:
# Type: Cycle
# Size: 3
# Nodes: 211, 730, 211
# Score: 2
# -------------------------------------------
# 31:
# Type: Cycle
# Size: 3
# Nodes: 217, 945, 217
# Score: 2
# -------------------------------------------
# 32:
# Type: Cycle
# Size: 3
# Nodes: 220, 764, 220
# Score: 2
# -------------------------------------------
# 33:
# Type: Cycle
# Size: 3
# Nodes: 221, 721, 221
# Score: 2
# -------------------------------------------
# 34:
# Type: Cycle
# Size: 3
# Nodes: 232, 33, 232
# Score: 2
# -------------------------------------------
# 35:
# Type: Cycle
# Size: 3
# Nodes: 242, 357, 242
# Score: 2
# -------------------------------------------
# 36:
# Type: Cycle
# Size: 3
# Nodes: 244, 342, 244
# Score: 2
# -------------------------------------------
# 37:
# Type: Cycle
# Size: 3
# Nodes: 250, 802, 250
# Score: 2
# -------------------------------------------
# 38:
# Type: Cycle
# Size: 3
# Nodes: 265, 540, 265
# Score: 2
# -------------------------------------------
# 39:
# Type: Cycle
# Size: 3
# Nodes: 269, 797, 269
# Score: 2
# -------------------------------------------
# 40:
# Type: Cycle
# Size: 3
# Nodes: 283, 829, 283
# Score: 2
# -------------------------------------------
# 41:
# Type: Cycle
# Size: 3
# Nodes: 291, 451, 291
# Score: 2
# -------------------------------------------
# 42:
# Type: Cycle
# Size: 3
# Nodes: 292, 140, 292
# Score: 2
# -------------------------------------------
# 43:
# Type: Cycle
# Size: 3
# Nodes: 296, 524, 296
# Score: 2
# -------------------------------------------
# 44:
# Type: Cycle
# Size: 3
# Nodes: 300, 940, 300
# Score: 2
# -------------------------------------------
# 45:
# Type: Cycle
# Size: 3
# Nodes: 302, 129, 302
# Score: 2
# -------------------------------------------
# 46:
# Type: Cycle
# Size: 3
# Nodes: 303, 162, 303
# Score: 2
# -------------------------------------------
# 47:
# Type: Cycle
# Size: 3
# Nodes: 331, 629, 331
# Score: 2
# -------------------------------------------
# 48:
# Type: Cycle
# Size: 3
# Nodes: 337, 508, 337
# Score: 2
# -------------------------------------------
# 49:
# Type: Cycle
# Size: 3
# Nodes: 346, 431, 346
# Score: 2
# -------------------------------------------
# 50:
# Type: Cycle
# Size: 3
# Nodes: 350, 144, 350
# Score: 2
# -------------------------------------------
# 51:
# Type: Cycle
# Size: 3
# Nodes: 363, 740, 363
# Score: 2
# -------------------------------------------
# 52:
# Type: Cycle
# Size: 3
# Nodes: 365, 285, 365
# Score: 2
# -------------------------------------------
# 53:
# Type: Cycle
# Size: 3
# Nodes: 374, 226, 374
# Score: 2
# -------------------------------------------
# 54:
# Type: Cycle
# Size: 3
# Nodes: 379, 937, 379
# Score: 2
# -------------------------------------------
# 55:
# Type: Cycle
# Size: 3
# Nodes: 382, 810, 382
# Score: 2
# -------------------------------------------
# 56:
# Type: Cycle
# Size: 3
# Nodes: 392, 115, 392
# Score: 2
# -------------------------------------------
# 57:
# Type: Cycle
# Size: 3
# Nodes: 393, 542, 393
# Score: 2
# -------------------------------------------
# 58:
# Type: Cycle
# Size: 3
# Nodes: 395, 426, 395
# Score: 2
# -------------------------------------------
# 59:
# Type: Cycle
# Size: 3
# Nodes: 401, 213, 401
# Score: 2
# -------------------------------------------
# 60:
# Type: Cycle
# Size: 3
# Nodes: 402, 70, 402
# Score: 2
# -------------------------------------------
# 61:
# Type: Cycle
# Size: 3
# Nodes: 406, 133, 406
# Score: 2
# -------------------------------------------
# 62:
# Type: Cycle
# Size: 3
# Nodes: 412, 604, 412
# Score: 2
# -------------------------------------------
# 63:
# Type: Cycle
# Size: 3
# Nodes: 419, 8, 419
# Score: 2
# -------------------------------------------
# 64:
# Type: Cycle
# Size: 3
# Nodes: 421, 316, 421
# Score: 2
# -------------------------------------------
# 65:
# Type: Cycle
# Size: 3
# Nodes: 422, 826, 422
# Score: 2
# -------------------------------------------
# 66:
# Type: Cycle
# Size: 3
# Nodes: 453, 153, 453
# Score: 2
# -------------------------------------------
# 67:
# Type: Cycle
# Size: 3
# Nodes: 458, 851, 458
# Score: 2
# -------------------------------------------
# 68:
# Type: Cycle
# Size: 3
# Nodes: 487, 917, 487
# Score: 2
# -------------------------------------------
# 69:
# Type: Cycle
# Size: 3
# Nodes: 488, 870, 488
# Score: 2
# -------------------------------------------
# 70:
# Type: Cycle
# Size: 3
# Nodes: 491, 247, 491
# Score: 2
# -------------------------------------------
# 71:
# Type: Cycle
# Size: 3
# Nodes: 504, 638, 504
# Score: 2
# -------------------------------------------
# 72:
# Type: Cycle
# Size: 3
# Nodes: 505, 815, 505
# Score: 2
# -------------------------------------------
# 73:
# Type: Cycle
# Size: 3
# Nodes: 512, 820, 512
# Score: 2
# -------------------------------------------
# 74:
# Type: Cycle
# Size: 3
# Nodes: 513, 415, 513
# Score: 2
# -------------------------------------------
# 75:
# Type: Cycle
# Size: 3
# Nodes: 522, 319, 522
# Score: 2
# -------------------------------------------
# 76:
# Type: Cycle
# Size: 3
# Nodes: 533, 528, 533
# Score: 2
# -------------------------------------------
# 77:
# Type: Cycle
# Size: 3
# Nodes: 535, 946, 535
# Score: 2
# -------------------------------------------
# 78:
# Type: Cycle
# Size: 3
# Nodes: 545, 753, 545
# Score: 2
# -------------------------------------------
# 79:
# Type: Cycle
# Size: 3
# Nodes: 546, 861, 546
# Score: 2
# -------------------------------------------
# 80:
# Type: Cycle
# Size: 3
# Nodes: 556, 785, 556
# Score: 2
# -------------------------------------------
# 81:
# Type: Cycle
# Size: 3
# Nodes: 558, 89, 558
# Score: 2
# -------------------------------------------
# 82:
# Type: Cycle
# Size: 3
# Nodes: 566, 687, 566
# Score: 2
# -------------------------------------------
# 83:
# Type: Cycle
# Size: 3
# Nodes: 580, 288, 580
# Score: 2
# -------------------------------------------
# 84:
# Type: Cycle
# Size: 3
# Nodes: 582, 224, 582
# Score: 2
# -------------------------------------------
# 85:
# Type: Cycle
# Size: 3
# Nodes: 586, 895, 586
# Score: 2
# -------------------------------------------
# 86:
# Type: Cycle
# Size: 3
# Nodes: 590, 751, 590
# Score: 2
# -------------------------------------------
# 87:
# Type: Cycle
# Size: 3
# Nodes: 599, 621, 599
# Score: 2
# -------------------------------------------
# 88:
# Type: Cycle
# Size: 3
# Nodes: 636, 832, 636
# Score: 2
# -------------------------------------------
# 89:
# Type: Cycle
# Size: 3
# Nodes: 642, 831, 642
# Score: 2
# -------------------------------------------
# 90:
# Type: Cycle
# Size: 3
# Nodes: 650, 121, 650
# Score: 2
# -------------------------------------------
# 91:
# Type: Cycle
# Size: 3
# Nodes: 660, 717, 660
# Score: 2
# -------------------------------------------
# 92:
# Type: Cycle
# Size: 3
# Nodes: 664, 174, 664
# Score: 2
# -------------------------------------------
# 93:
# Type: Cycle
# Size: 3
# Nodes: 673, 727, 673
# Score: 2
# -------------------------------------------
# 94:
# Type: Cycle
# Size: 3
# Nodes: 677, 259, 677
# Score: 2
# -------------------------------------------
# 95:
# Type: Cycle
# Size: 3
# Nodes: 680, 858, 680
# Score: 2
# -------------------------------------------
# 96:
# Type: Cycle
# Size: 3
# Nodes: 684, 57, 684
# Score: 2
# -------------------------------------------
# 97:
# Type: Cycle
# Size: 3
# Nodes: 685, 49, 685
# Score: 2
# -------------------------------------------
# 98:
# Type: Cycle
# Size: 3
# Nodes: 689, 241, 689
# Score: 2
# -------------------------------------------
# 99:
# Type: Cycle
# Size: 3
# Nodes: 690, 725, 690
# Score: 2
# -------------------------------------------
# 100:
# Type: Cycle
# Size: 3
# Nodes: 694, 878, 694
# Score: 2
# -------------------------------------------
# 101:
# Type: Cycle
# Size: 3
# Nodes: 695, 371, 695
# Score: 2
# -------------------------------------------
# 102:
# Type: Cycle
# Size: 3
# Nodes: 703, 688, 703
# Score: 2
# -------------------------------------------
# 103:
# Type: Cycle
# Size: 3
# Nodes: 713, 780, 713
# Score: 2
# -------------------------------------------
# Selected Paths:
# Total score: 206
#
# Optimization information:
# optimal_solution_found: True
# total_time_s: 0.5016381740570068
# number_of_variables: 2444
# number_of_constraints: 1000
# number_of_non_zeros: 4888
# objective_1_max_cycles_and_chains: 103
# objective_2_min_cycles_and_chains_of_size_4: 0
# objective_3_min_cycles_chains_of_size_3: 0
# objective_4_max_total_score_weight: 206

# %% [markdown]
# # Process and save multiple optimization processes in one run

# %%
def save_solution(filepath, solution, output_folder):
    """
    Saves the solution of each file in the output folder, including optimization info.
    
    Args:
        filepath (str): The path to the text file containing the kidney exchange data.
        solution (dict): The solution data to be saved.
        output_folder (str): The path to the folder where solutions should be saved.
    """
    # Step 1: Extract the filename without the extension
    filename = os.path.basename(filepath)
    file_base_name = os.path.splitext(filename)[0]

    # Step 2: Create the solution file path inside the output folder
    solution_file_path = os.path.join(output_folder, f"{file_base_name}_solution.txt")
    
    # Step 3: Save the solution in the file
    with open(solution_file_path, 'w') as f:
        f.write("Selected Cycles:\n")
        for idx, cycle in enumerate(solution['selected_cycles']):
            f.write(f"{idx + 1}:\n")
            f.write(f"Type: {cycle['type']}\n")
            f.write(f"Size: {cycle['size']}\n")
            f.write(f"Nodes: {cycle['nodes']}\n")
            f.write(f"Score: {cycle['score']}\n")
            f.write("-------------------------------------------\n")
        
        f.write("\nSelected Paths:\n")
        for idx, path in enumerate(solution['selected_paths']):
            f.write(f"{idx + 1}:\n")
            f.write(f"Type: {path['type']}\n")
            f.write(f"Size: {path['size']}\n")
            f.write(f"Nodes: {path['nodes']}\n")
            f.write(f"Score: {path['score']}\n")
            f.write("-------------------------------------------\n")
        
        f.write(f"Total score: {solution['total_score']}\n")
        
        # Step 4: Add optimization information
        f.write("\nOptimization information:\n")
        for key, value in solution['optimization_info'].items():
            f.write(f"{key}: {value}\n")
    
    print(f"Solution saved in {solution_file_path}")
    time.sleep(0.1)

# %%
def process_files(directory, output_folder):
    """
    Processes all relevant files in the directory, computes solutions, and saves them in the output folder.
    """
    prefixes = ["Delorme", "RandomSparse", "Saidman"]
    files = [f for f in os.listdir(directory) if any(f.startswith(prefix) for prefix in prefixes) and f.endswith('.txt')]

    for file in files:
        filepath = os.path.join(directory, file)
        print(f"Processing file: {filepath}")
        
        # Import the kidney exchange data from the file
        data = import_kidney_data(filepath)
        
        # Create a directed graph from the data
        G = create_graph(data)

        # **NEW STEP: Calculate cycles and paths**
        cycles, paths = calculate_cycles_and_paths(G, data)
        
        # Solve the kidney exchange problem
        solution = solve_kidney_exchange(G, cycles, paths)
        
        # Save the solution in the designated output folder
        save_solution(filepath, solution, output_folder)
        print(f"Results saved for file: {file}\n")

# Define your input directory and the output folder
input_directory = "C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files"
output_folder = "C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound"

# Ensure that the output folder exists
os.makedirs(output_folder, exist_ok=True)

# Process all the files in the input directory
process_files(input_directory, output_folder)
# Out:
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Delorme_1000_NDD_Unit_0.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 9132 columns and 18264 nonzeros
# Model fingerprint: 0x0909ecd7
# Variable types: 0 continuous, 9132 integer (9132 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 246.0000000
# Presolve removed 948 rows and 8833 columns
# Presolve time: 0.04s
# Presolved: 52 rows, 299 columns, 598 nonzeros
# Found heuristic solution: objective 258.0000000
# Variable types: 0 continuous, 299 integer (299 binary)
#
# Root relaxation: interrupted, 42 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0       258.00000  260.00000  0.78%     -    0s
#
# Explored 1 nodes (42 simplex iterations) in 0.09 seconds (0.02 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 258 246
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 2.580000000000e+02, best bound 2.600000000000e+02, gap 0.7752%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Delorme_1000_NDD_Unit_0_solution.txt
# Results saved for file: Delorme_1000_NDD_Unit_0.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Delorme_1000_NDD_Unit_1.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 8013 columns and 16026 nonzeros
# Model fingerprint: 0xbd22a2e8
# Variable types: 0 continuous, 8013 integer (8013 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 243.0000000
# Presolve removed 966 rows and 7856 columns
# Presolve time: 0.04s
# Presolved: 34 rows, 157 columns, 314 nonzeros
# Found heuristic solution: objective 257.0000000
# Variable types: 0 continuous, 157 integer (157 binary)
#
# Root relaxation: interrupted, 45 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0       257.00000  259.00000  0.78%     -    0s
#
# Explored 1 nodes (45 simplex iterations) in 0.08 seconds (0.02 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 257 243
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 2.570000000000e+02, best bound 2.590000000000e+02, gap 0.7782%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Delorme_1000_NDD_Unit_1_solution.txt
# Results saved for file: Delorme_1000_NDD_Unit_1.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Delorme_1000_NDD_Unit_2.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 8375 columns and 16750 nonzeros
# Model fingerprint: 0xa6695362
# Variable types: 0 continuous, 8375 integer (8375 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 228.0000000
# Presolve removed 1000 rows and 8375 columns
# Presolve time: 0.03s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 236 228
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 2.360000000000e+02, best bound 2.360000000000e+02, gap 0.0000%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Delorme_1000_NDD_Unit_2_solution.txt
# Results saved for file: Delorme_1000_NDD_Unit_2.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Delorme_1000_NDD_Unit_3.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 8446 columns and 16892 nonzeros
# Model fingerprint: 0xac0cad4a
# Variable types: 0 continuous, 8446 integer (8446 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 225.0000000
# Presolve removed 971 rows and 8321 columns
# Presolve time: 0.02s
# Presolved: 29 rows, 125 columns, 249 nonzeros
# Found heuristic solution: objective 238.0000000
# Variable types: 0 continuous, 125 integer (125 binary)
#
# Root relaxation: cutoff, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       238.00000  238.00000  0.00%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.06 seconds (0.01 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 238 225
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 2.380000000000e+02, best bound 2.380000000000e+02, gap 0.0000%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Delorme_1000_NDD_Unit_3_solution.txt
# Results saved for file: Delorme_1000_NDD_Unit_3.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Delorme_1000_NDD_Unit_4.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 8531 columns and 17062 nonzeros
# Model fingerprint: 0x58ded03d
# Variable types: 0 continuous, 8531 integer (8531 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 252.0000000
# Presolve removed 946 rows and 8370 columns
# Presolve time: 0.05s
# Presolved: 54 rows, 161 columns, 322 nonzeros
# Found heuristic solution: objective 264.0000000
# Variable types: 0 continuous, 161 integer (161 binary)
#
# Root relaxation: cutoff, 25 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       264.00000  264.00000  0.00%     -    0s
#
# Explored 1 nodes (25 simplex iterations) in 0.09 seconds (0.02 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 264 252
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 2.640000000000e+02, best bound 2.640000000000e+02, gap 0.0000%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Delorme_1000_NDD_Unit_4_solution.txt
# Results saved for file: Delorme_1000_NDD_Unit_4.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Delorme_1000_NDD_Weight_0.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 9132 columns and 18264 nonzeros
# Model fingerprint: 0x87c531a9
# Variable types: 0 continuous, 9132 integer (9132 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 11236.000000
# Presolve removed 885 rows and 8331 columns
# Presolve time: 0.06s
# Presolved: 115 rows, 801 columns, 1578 nonzeros
# Found heuristic solution: objective 16508.000000
# Variable types: 0 continuous, 801 integer (801 binary)
# Found heuristic solution: objective 16614.000000
#
# Root relaxation: objective 1.714400e+04, 116 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    17144.000000 17144.0000  0.00%     -    0s
#
# Explored 1 nodes (116 simplex iterations) in 0.11 seconds (0.04 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 17144 16614 16508 11236
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.714400000000e+04, best bound 1.714400000000e+04, gap 0.0000%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Delorme_1000_NDD_Weight_0_solution.txt
# Results saved for file: Delorme_1000_NDD_Weight_0.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Delorme_1000_NDD_Weight_1.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 8013 columns and 16026 nonzeros
# Model fingerprint: 0xd3082331
# Variable types: 0 continuous, 8013 integer (8013 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 11731.000000
# Presolve removed 900 rows and 7448 columns
# Presolve time: 0.07s
# Presolved: 100 rows, 565 columns, 1116 nonzeros
# Found heuristic solution: objective 15923.000000
# Variable types: 0 continuous, 565 integer (565 binary)
# Found heuristic solution: objective 16009.000000
#
# Root relaxation: objective 1.667900e+04, 129 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    16679.000000 16679.0000  0.00%     -    0s
#
# Explored 1 nodes (129 simplex iterations) in 0.09 seconds (0.04 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 16679 16009 15923 11731
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.667900000000e+04, best bound 1.667900000000e+04, gap 0.0000%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Delorme_1000_NDD_Weight_1_solution.txt
# Results saved for file: Delorme_1000_NDD_Weight_1.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Delorme_1000_NDD_Weight_2.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 8375 columns and 16750 nonzeros
# Model fingerprint: 0x741b6195
# Variable types: 0 continuous, 8375 integer (8375 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 9829.0000000
# Presolve removed 916 rows and 8033 columns
# Presolve time: 0.05s
# Presolved: 84 rows, 342 columns, 671 nonzeros
# Found heuristic solution: objective 15312.000000
# Variable types: 0 continuous, 342 integer (342 binary)
# Found heuristic solution: objective 15339.000000
#
# Root relaxation: objective 1.549700e+04, 92 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    15497.000000 15497.0000  0.00%     -    0s
#
# Explored 1 nodes (92 simplex iterations) in 0.09 seconds (0.03 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 15497 15339 15312 9829
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.549700000000e+04, best bound 1.549700000000e+04, gap 0.0000%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Delorme_1000_NDD_Weight_2_solution.txt
# Results saved for file: Delorme_1000_NDD_Weight_2.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Delorme_1000_NDD_Weight_3.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 8446 columns and 16892 nonzeros
# Model fingerprint: 0x70386b1e
# Variable types: 0 continuous, 8446 integer (8446 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 9894.0000000
# Presolve removed 920 rows and 8038 columns
# Presolve time: 0.05s
# Presolved: 80 rows, 408 columns, 797 nonzeros
# Found heuristic solution: objective 14890.000000
# Variable types: 0 continuous, 408 integer (408 binary)
# Found heuristic solution: objective 15082.000000
#
# Root relaxation: objective 1.538800e+04, 83 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    15388.000000 15388.0000  0.00%     -    0s
#
# Explored 1 nodes (83 simplex iterations) in 0.08 seconds (0.04 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 15388 15082 14890 9894
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.538800000000e+04, best bound 1.538800000000e+04, gap 0.0000%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Delorme_1000_NDD_Weight_3_solution.txt
# Results saved for file: Delorme_1000_NDD_Weight_3.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Delorme_1000_NDD_Weight_4.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 8531 columns and 17062 nonzeros
# Model fingerprint: 0x0a3a566b
# Variable types: 0 continuous, 8531 integer (8531 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 11540.000000
# Presolve removed 888 rows and 7947 columns
# Presolve time: 0.05s
# Presolved: 112 rows, 584 columns, 1158 nonzeros
# Found heuristic solution: objective 16225.000000
# Variable types: 0 continuous, 584 integer (584 binary)
# Found heuristic solution: objective 16281.000000
#
# Root relaxation: objective 1.654600e+04, 113 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    16546.000000 16546.0000  0.00%     -    0s
#
# Explored 1 nodes (113 simplex iterations) in 0.08 seconds (0.03 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 16546 16281 16225 11540
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.654600000000e+04, best bound 1.654600000000e+04, gap 0.0000%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Delorme_1000_NDD_Weight_4_solution.txt
# Results saved for file: Delorme_1000_NDD_Weight_4.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Delorme_1000_NoNDD_Unit_0.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 3246 columns and 6492 nonzeros
# Model fingerprint: 0x27375eb9
# Variable types: 0 continuous, 3246 integer (3246 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 218.0000000
# Presolve removed 964 rows and 3096 columns
# Presolve time: 0.01s
# Presolved: 36 rows, 150 columns, 300 nonzeros
# Found heuristic solution: objective 234.0000000
# Variable types: 0 continuous, 150 integer (150 binary)
#
# Root relaxation: interrupted, 27 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0       234.00000  236.00000  0.85%     -    0s
#
# Explored 1 nodes (27 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 234 218
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 2.340000000000e+02, best bound 2.360000000000e+02, gap 0.8547%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Delorme_1000_NoNDD_Unit_0_solution.txt
# Results saved for file: Delorme_1000_NoNDD_Unit_0.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Delorme_1000_NoNDD_Unit_1.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 2174 columns and 4348 nonzeros
# Model fingerprint: 0x9b4891de
# Variable types: 0 continuous, 2174 integer (2174 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 192.0000000
# Presolve removed 970 rows and 2072 columns
# Presolve time: 0.01s
# Presolved: 30 rows, 102 columns, 204 nonzeros
# Found heuristic solution: objective 212.0000000
# Variable types: 0 continuous, 102 integer (102 binary)
#
# Root relaxation: interrupted, 23 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0       212.00000  214.00000  0.94%     -    0s
#
# Explored 1 nodes (23 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 212 192
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 2.120000000000e+02, best bound 2.140000000000e+02, gap 0.9434%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Delorme_1000_NoNDD_Unit_1_solution.txt
# Results saved for file: Delorme_1000_NoNDD_Unit_1.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Delorme_1000_NoNDD_Unit_2.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 2100 columns and 4200 nonzeros
# Model fingerprint: 0x33e80976
# Variable types: 0 continuous, 2100 integer (2100 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 178.0000000
# Presolve removed 1000 rows and 2100 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 186 178
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.860000000000e+02, best bound 1.860000000000e+02, gap 0.0000%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Delorme_1000_NoNDD_Unit_2_solution.txt
# Results saved for file: Delorme_1000_NoNDD_Unit_2.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Delorme_1000_NoNDD_Unit_3.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 1810 columns and 3620 nonzeros
# Model fingerprint: 0x9d09383d
# Variable types: 0 continuous, 1810 integer (1810 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 192.0000000
# Presolve removed 979 rows and 1737 columns
# Presolve time: 0.01s
# Presolved: 21 rows, 73 columns, 146 nonzeros
# Found heuristic solution: objective 200.0000000
# Variable types: 0 continuous, 73 integer (73 binary)
#
# Root relaxation: objective 2.020000e+02, 14 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     202.0000000  202.00000  0.00%     -    0s
#
# Explored 1 nodes (14 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 202 200 192
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 2.020000000000e+02, best bound 2.020000000000e+02, gap 0.0000%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Delorme_1000_NoNDD_Unit_3_solution.txt
# Results saved for file: Delorme_1000_NoNDD_Unit_3.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Delorme_1000_NoNDD_Unit_4.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 1484 columns and 2968 nonzeros
# Model fingerprint: 0xfac1c7c8
# Variable types: 0 continuous, 1484 integer (1484 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 190.0000000
# Presolve removed 973 rows and 1396 columns
# Presolve time: 0.00s
# Presolved: 27 rows, 88 columns, 176 nonzeros
# Found heuristic solution: objective 196.0000000
# Variable types: 0 continuous, 88 integer (88 binary)
#
# Root relaxation: objective 1.980000e+02, 40 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     198.0000000  198.00000  0.00%     -    0s
#
# Explored 1 nodes (40 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 198 196 190
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.980000000000e+02, best bound 1.980000000000e+02, gap 0.0000%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Delorme_1000_NoNDD_Unit_4_solution.txt
# Results saved for file: Delorme_1000_NoNDD_Unit_4.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Delorme_1000_NoNDD_Weight_0.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 3246 columns and 6492 nonzeros
# Model fingerprint: 0x487b7476
# Variable types: 0 continuous, 3246 integer (3246 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 9801.0000000
# Presolve removed 957 rows and 3034 columns
# Presolve time: 0.02s
# Presolved: 43 rows, 212 columns, 418 nonzeros
# Found heuristic solution: objective 14174.000000
# Variable types: 0 continuous, 212 integer (212 binary)
# Found heuristic solution: objective 14263.000000
#
# Root relaxation: interrupted, 45 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      14263.0000 14404.0000  0.99%     -    0s
#
# Explored 1 nodes (45 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 14263 14174 9801
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.426300000000e+04, best bound 1.440400000000e+04, gap 0.9886%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Delorme_1000_NoNDD_Weight_0_solution.txt
# Results saved for file: Delorme_1000_NoNDD_Weight_0.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Delorme_1000_NoNDD_Weight_1.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 2174 columns and 4348 nonzeros
# Model fingerprint: 0x76415820
# Variable types: 0 continuous, 2174 integer (2174 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 8165.0000000
# Presolve removed 957 rows and 2008 columns
# Presolve time: 0.01s
# Presolved: 43 rows, 166 columns, 329 nonzeros
# Found heuristic solution: objective 11745.000000
# Variable types: 0 continuous, 166 integer (166 binary)
# Found heuristic solution: objective 11858.000000
#
# Root relaxation: interrupted, 27 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      11858.0000 11971.0000  0.95%     -    0s
#
# Explored 1 nodes (27 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 11858 11745 8165
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.185800000000e+04, best bound 1.197100000000e+04, gap 0.9529%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Delorme_1000_NoNDD_Weight_1_solution.txt
# Results saved for file: Delorme_1000_NoNDD_Weight_1.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Delorme_1000_NoNDD_Weight_2.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 2100 columns and 4200 nonzeros
# Model fingerprint: 0x805f81d3
# Variable types: 0 continuous, 2100 integer (2100 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [5e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 8179.0000000
# Presolve removed 987 rows and 2083 columns
# Presolve time: 0.00s
# Presolved: 13 rows, 17 columns, 34 nonzeros
# Found heuristic solution: objective 11088.000000
# Variable types: 0 continuous, 17 integer (17 binary)
# Found heuristic solution: objective 11096.000000
#
# Root relaxation: interrupted, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 11096 11088 8179
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.109600000000e+04, best bound 1.120400000000e+04, gap 0.9733%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Delorme_1000_NoNDD_Weight_2_solution.txt
# Results saved for file: Delorme_1000_NoNDD_Weight_2.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Delorme_1000_NoNDD_Weight_3.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 1810 columns and 3620 nonzeros
# Model fingerprint: 0x0e55f650
# Variable types: 0 continuous, 1810 integer (1810 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 9097.0000000
# Presolve removed 973 rows and 1705 columns
# Presolve time: 0.01s
# Presolved: 27 rows, 105 columns, 208 nonzeros
# Found heuristic solution: objective 11847.000000
# Variable types: 0 continuous, 105 integer (105 binary)
#
# Root relaxation: objective 1.198600e+04, 19 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    11986.000000 11986.0000  0.00%     -    0s
#
# Explored 1 nodes (19 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 11986 11847 9097
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.198600000000e+04, best bound 1.198600000000e+04, gap 0.0000%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Delorme_1000_NoNDD_Weight_3_solution.txt
# Results saved for file: Delorme_1000_NoNDD_Weight_3.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Delorme_1000_NoNDD_Weight_4.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 1484 columns and 2968 nonzeros
# Model fingerprint: 0xa51434f6
# Variable types: 0 continuous, 1484 integer (1484 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 8695.0000000
# Presolve removed 964 rows and 1368 columns
# Presolve time: 0.01s
# Presolved: 36 rows, 116 columns, 228 nonzeros
# Found heuristic solution: objective 11734.000000
# Variable types: 0 continuous, 116 integer (116 binary)
# Found heuristic solution: objective 11760.000000
#
# Root relaxation: interrupted, 33 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0      11760.0000 11869.0000  0.93%     -    0s
#
# Explored 1 nodes (33 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 11760 11734 8695
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.176000000000e+04, best bound 1.186900000000e+04, gap 0.9269%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Delorme_1000_NoNDD_Weight_4_solution.txt
# Results saved for file: Delorme_1000_NoNDD_Weight_4.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Delorme_200_NDD_Unit_0.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 200 rows, 410 columns and 820 nonzeros
# Model fingerprint: 0xea4d40d7
# Variable types: 0 continuous, 410 integer (410 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 24.0000000
# Presolve removed 200 rows and 410 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 24
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 2.400000000000e+01, best bound 2.400000000000e+01, gap 0.0000%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Delorme_200_NDD_Unit_0_solution.txt
# Results saved for file: Delorme_200_NDD_Unit_0.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Delorme_200_NDD_Unit_1.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 200 rows, 414 columns and 828 nonzeros
# Model fingerprint: 0xaecfd0e6
# Variable types: 0 continuous, 414 integer (414 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 34.0000000
# Presolve removed 193 rows and 405 columns
# Presolve time: 0.00s
# Presolved: 7 rows, 9 columns, 18 nonzeros
# Variable types: 0 continuous, 9 integer (9 binary)
#
# Root relaxation: cutoff, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0        34.00000   34.00000  0.00%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 34
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 3.400000000000e+01, best bound 3.400000000000e+01, gap 0.0000%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Delorme_200_NDD_Unit_1_solution.txt
# Results saved for file: Delorme_200_NDD_Unit_1.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Delorme_200_NDD_Unit_2.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 200 rows, 390 columns and 780 nonzeros
# Model fingerprint: 0x8a728c89
# Variable types: 0 continuous, 390 integer (390 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 39.0000000
# Presolve removed 200 rows and 390 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 42 39
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 4.200000000000e+01, best bound 4.200000000000e+01, gap 0.0000%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Delorme_200_NDD_Unit_2_solution.txt
# Results saved for file: Delorme_200_NDD_Unit_2.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Delorme_200_NDD_Unit_3.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 200 rows, 364 columns and 728 nonzeros
# Model fingerprint: 0x6dd7bebd
# Variable types: 0 continuous, 364 integer (364 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 35.0000000
# Presolve removed 200 rows and 364 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 35
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 3.500000000000e+01, best bound 3.500000000000e+01, gap 0.0000%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Delorme_200_NDD_Unit_3_solution.txt
# Results saved for file: Delorme_200_NDD_Unit_3.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Delorme_200_NDD_Unit_4.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 200 rows, 272 columns and 544 nonzeros
# Model fingerprint: 0x78ce11a4
# Variable types: 0 continuous, 272 integer (272 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 22.0000000
# Presolve removed 194 rows and 264 columns
# Presolve time: 0.00s
# Presolved: 6 rows, 8 columns, 16 nonzeros
# Found heuristic solution: objective 22.0000000
# Variable types: 0 continuous, 8 integer (8 binary)
#
# Root relaxation: cutoff, 0 iterations, 0.00 seconds (0.00 work units)
#
# Explored 1 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 22 22
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 2.200000000000e+01, best bound 2.200000000000e+01, gap 0.0000%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Delorme_200_NDD_Unit_4_solution.txt
# Results saved for file: Delorme_200_NDD_Unit_4.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Delorme_200_NDD_Weight_0.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 200 rows, 410 columns and 820 nonzeros
# Model fingerprint: 0xcfde2084
# Variable types: 0 continuous, 410 integer (410 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 963.0000000
# Presolve removed 200 rows and 410 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 1422 963
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.422000000000e+03, best bound 1.422000000000e+03, gap 0.0000%
# Optimal solution found!
# ...
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 21327.000000
# Presolve removed 2 rows and 21249 columns
# Presolve time: 0.18s
# Presolved: 998 rows, 39475 columns, 78949 nonzeros
# Found heuristic solution: objective 32116.000000
# Variable types: 0 continuous, 39475 integer (39475 binary)
# Found heuristic solution: objective 33432.000000
#
# Root relaxation: objective 3.787000e+04, 1584 iterations, 0.05 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 37870.0000    0    6 33432.0000 37870.0000  13.3%     -    0s
# H    0     0                    37767.000000 37870.0000  0.27%     -    0s
#
# Explored 1 nodes (1584 simplex iterations) in 0.47 seconds (0.51 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 37767 33432 32116 21327
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 3.776700000000e+04, best bound 3.787000000000e+04, gap 0.2727%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Saidman_1000_NDD_Weight_3_solution.txt
# Results saved for file: Saidman_1000_NDD_Weight_3.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Saidman_1000_NDD_Weight_4.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 71438 columns and 142876 nonzeros
# Model fingerprint: 0x97c5359c
# Variable types: 0 continuous, 71438 integer (71438 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 22546.000000
# Presolve removed 2 rows and 26972 columns
# Presolve time: 0.54s
# Presolved: 998 rows, 44466 columns, 88931 nonzeros
# Found heuristic solution: objective 34416.000000
# Variable types: 0 continuous, 44466 integer (44466 binary)
# Found heuristic solution: objective 36352.000000
#
# Root relaxation: objective 4.107600e+04, 1680 iterations, 0.14 seconds (0.08 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 41076.0000    0    3 36352.0000 41076.0000  13.0%     -    1s
# H    0     0                    41049.000000 41076.0000  0.07%     -    1s
#
# Explored 1 nodes (1680 simplex iterations) in 1.20 seconds (0.62 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 41049 36352 34416 22546
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 4.104900000000e+04, best bound 4.107600000000e+04, gap 0.0658%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Saidman_1000_NDD_Weight_4_solution.txt
# Results saved for file: Saidman_1000_NDD_Weight_4.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Saidman_1000_NoNDD_Unit_0.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 50306 columns and 100612 nonzeros
# Model fingerprint: 0x8f796dae
# Variable types: 0 continuous, 50306 integer (50306 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 484.0000000
# Presolve removed 280 rows and 31509 columns
# Presolve time: 0.76s
# Presolved: 720 rows, 18797 columns, 37594 nonzeros
# Found heuristic solution: objective 484.0000000
# Variable types: 0 continuous, 18797 integer (18797 binary)
#
# Root relaxation: objective 5.140000e+02, 1377 iterations, 0.16 seconds (0.08 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  514.00000    0    6  484.00000  514.00000  6.20%     -    1s
# H    0     0                     512.0000000  514.00000  0.39%     -    1s
#
# Explored 1 nodes (4126 simplex iterations) in 1.36 seconds (0.53 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 512 484 484
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 5.120000000000e+02, best bound 5.140000000000e+02, gap 0.3906%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Saidman_1000_NoNDD_Unit_0_solution.txt
# Results saved for file: Saidman_1000_NoNDD_Unit_0.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Saidman_1000_NoNDD_Unit_1.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 53312 columns and 106624 nonzeros
# Model fingerprint: 0x9d178b41
# Variable types: 0 continuous, 53312 integer (53312 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 456.0000000
# Presolve removed 302 rows and 36385 columns
# Presolve time: 0.25s
# Presolved: 698 rows, 16927 columns, 33854 nonzeros
# Found heuristic solution: objective 458.0000000
# Variable types: 0 continuous, 16927 integer (16927 binary)
#
# Root relaxation: objective 4.790000e+02, 1293 iterations, 0.06 seconds (0.07 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  479.00000    0    3  458.00000  479.00000  4.59%     -    0s
# H    0     0                     478.0000000  479.00000  0.21%     -    0s
#      0     0  479.00000    0    3  478.00000  479.00000  0.21%     -    0s
#
# Explored 1 nodes (1293 simplex iterations) in 0.52 seconds (0.41 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 478 458 456
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 4.780000000000e+02, best bound 4.780000000000e+02, gap 0.0000%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Saidman_1000_NoNDD_Unit_1_solution.txt
# Results saved for file: Saidman_1000_NoNDD_Unit_1.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Saidman_1000_NoNDD_Unit_2.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 64742 columns and 129484 nonzeros
# Model fingerprint: 0xa45dbbce
# Variable types: 0 continuous, 64742 integer (64742 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 526.0000000
# Presolve removed 116 rows and 40927 columns
# Presolve time: 0.35s
# Presolved: 884 rows, 23815 columns, 47630 nonzeros
# Found heuristic solution: objective 528.0000000
# Variable types: 0 continuous, 23815 integer (23815 binary)
#
# Root relaxation: objective 5.490000e+02, 2012 iterations, 0.08 seconds (0.11 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  549.00000    0    3  528.00000  549.00000  3.98%     -    0s
# H    0     0                     548.0000000  549.00000  0.18%     -    0s
#      0     0  549.00000    0    3  548.00000  549.00000  0.18%     -    0s
#
# Explored 1 nodes (2012 simplex iterations) in 0.54 seconds (0.60 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 548 528 526
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 5.480000000000e+02, best bound 5.480000000000e+02, gap 0.0000%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Saidman_1000_NoNDD_Unit_2_solution.txt
# Results saved for file: Saidman_1000_NoNDD_Unit_2.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Saidman_1000_NoNDD_Unit_3.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 51942 columns and 103884 nonzeros
# Model fingerprint: 0xbec9733e
# Variable types: 0 continuous, 51942 integer (51942 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 488.0000000
# Presolve removed 178 rows and 35728 columns
# Presolve time: 0.31s
# Presolved: 822 rows, 16214 columns, 32428 nonzeros
# Found heuristic solution: objective 488.0000000
# Variable types: 0 continuous, 16214 integer (16214 binary)
#
# Root relaxation: objective 5.150000e+02, 1527 iterations, 0.05 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  515.00000    0    5  488.00000  515.00000  5.53%     -    0s
# H    0     0                     514.0000000  515.00000  0.19%     -    0s
#      0     0  515.00000    0    5  514.00000  515.00000  0.19%     -    0s
#
# Explored 1 nodes (1527 simplex iterations) in 0.50 seconds (0.37 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 514 488 488
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 5.140000000000e+02, best bound 5.140000000000e+02, gap 0.0000%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Saidman_1000_NoNDD_Unit_3_solution.txt
# Results saved for file: Saidman_1000_NoNDD_Unit_3.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Saidman_1000_NoNDD_Unit_4.txt
# Set parameter TimeLimit to value 300
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1000 rows, 43698 columns and 87396 nonzeros
# Model fingerprint: 0x1aef5487
# Variable types: 0 continuous, 43698 integer (43698 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 454.0000000
# Presolve removed 344 rows and 34907 columns
# Presolve time: 0.32s
# Presolved: 656 rows, 8791 columns, 17582 nonzeros
# Found heuristic solution: objective 454.0000000
# Variable types: 0 continuous, 8791 integer (8791 binary)
#
# Root relaxation: objective 4.830000e+02, 1390 iterations, 0.03 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  483.00000    0    3  454.00000  483.00000  6.39%     -    0s
# H    0     0                     482.0000000  483.00000  0.21%     -    0s
#      0     0  483.00000    0    3  482.00000  483.00000  0.21%     -    0s
#
# Explored 1 nodes (1390 simplex iterations) in 0.43 seconds (0.30 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 482 454 454
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 4.820000000000e+02, best bound 4.820000000000e+02, gap 0.0000%
# Optimal solution found!
# Solution saved in C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound\Saidman_1000_NoNDD_Unit_4_solution.txt
# Results saved for file: Saidman_1000_NoNDD_Unit_4.txt
#
# Processing file: C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files\Saidman_1000_NoNDD_Weight_0.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[93], line 36
#      33 os.makedirs(output_folder, exist_ok=True)
#      35 # Process all the files in the input directory
# ---> 36 process_files(input_directory, output_folder)
#
# Cell In[93], line 19, in process_files(directory, output_folder)
#      16 G = create_graph(data)
#      18 # **NEW STEP: Calculate cycles and paths**
# ---> 19 cycles, paths = calculate_cycles_and_paths(G, data)
#      21 # Solve the kidney exchange problem
#      22 solution = solve_kidney_exchange(G, cycles, paths)
#
# Cell In[87], line 27, in calculate_cycles_and_paths(G, data, k)
#      25 for n in range(1, len(cyc)):
#      26     cyc_success += data['pairs'][cyc[n]]['patient_vpra']  # Sum up the vPRA values of patients in the cycle
# ---> 27     cyc_weight += set_weight(data['arcs'], cyc[n-1], cyc[n])  # Add the weight of the arc between consecutive pairs in the cycle
#      28 # Append the cycle info to the list 'c'
#      29 c.append({'id': id_count,'cycle': cyc, 'vpra_sum': cyc_success, 'weight_sum': cyc_weight})
#
# Cell In[84], line 84, in set_weight(dict_list, donor_id, patient_id, weight_key)
#      71 """
#      72 Retrieve the weight of an arc between a donor and a patient.
#      73
#    (...)
#      81     int: The weight of the arc if found, otherwise None.
#      82 """
#      83 for dct in dict_list:
# ---> 84     if dct.get("donor_id") == donor_id and dct.get("patient_id") == patient_id:
#      85         return dct.get(weight_key)
#      86 return None
#
# KeyboardInterrupt:
