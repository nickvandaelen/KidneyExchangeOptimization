# %%
#IMPORT NECESSARY LIBRARIES

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
import time
import gurobipy as gp
from gurobipy import GRB
import networkx as nx

# %%
# filepath = "C:/Users/20204018/OneDrive - TU Eindhoven/Documents/Master DSAI/YEAR 1 Q1/Optimization For DS/KidneyExchangeOptimization/Instance Files/Delorme_1000_NDD_Unit_0.txt"

# %%
def import_kidney_data(filepath):
    """
    Imports kidney exchange data from a text file and structures it into a dictionary.

    Args:
        filepath (str): The path to the text file containing the kidney exchange data.

    Returns:
        dict: A dictionary containing the following keys:
            - num_pairs (int): The number of pairs (donor-patient pairs) in the instance.
            - num_ndd (int): The number of non-directed donors (NDDs) in the instance.
            - num_arcs (int): The total number of arcs in the instance.
            - pairs (list): A list of dictionaries, each representing a pair or NDD with the following keys:
                - id (int): The unique ID of the pair.
                - is_ndd (bool): True if the pair is an NDD, False otherwise.
                - donor_blood_type (int): Donor's blood type (0 = A, 1 = B, 2 = AB, 3 = O).
                - patient_blood_type (int): Patient's blood type (0 = A, 1 = B, 2 = AB, 3 = O).
                - patient_vpra (int): Patient's vPRA score (0 = below 0.5, 1 = between 0.5 and 0.85, 2 = above 0.85).
            - arcs (list): A list of dictionaries representing the arcs between pairs with the following keys:
                - donor_id (int): ID of the donor pair.
                - patient_id (int): ID of the patient pair.
                - weight (int): The weight of the arc (always 1 in this case).

    Example:
        data = import_kidney_data('path/to/data.txt')
        print(data['num_pairs'])  # Output: Number of pairs in the instance
    """

    data = {}
    
    # Open the file and read all lines into memory
    with open(filepath, 'r') as f:
        lines = f.readlines()
        
        # Parse metadata: number of pairs, NDDs, and arcs
        num_pairs = int(lines[0].split(' ')[2])
        num_ndd = int(lines[1].split(' ')[2])
        num_arcs = int(lines[2].split(' ')[2])
        
        # Store the parsed values in the data dictionary
        data['num_pairs'] = num_pairs
        data['num_ndd'] = num_ndd
        data['num_arcs'] = num_arcs
        
        # Total number of entities (pairs + NDDs)
        num_things = num_pairs + num_ndd
        
        # List to store information about pairs and NDDs
        pairs = []
        
        # Parse each line corresponding to pairs and NDDs
        for line in lines[3:num_things + 3]:
            id, is_ndd, donor_blood_type, patient_blood_type, patient_vpra = map(int, line.strip().split(','))
            
            # Add pair/NDD info to the list
            pairs.append({
                'id': id,
                'is_ndd': bool(is_ndd),
                'donor_blood_type': donor_blood_type,
                'patient_blood_type': patient_blood_type,
                'patient_vpra': patient_vpra,
            })
        
        # Store the pairs data in the dictionary
        data['pairs'] = pairs

        # List to store information about arcs
        arcs = []
        
        # Parse each line corresponding to arcs (donor-patient relationships)
        for line in lines[num_things + 3:]:
            arc, weight = line.strip().split(',1,')
            
            # Extract donor and patient IDs from the arc
            donor_id, patient_id = arc.split(',')
            weight = int(weight.strip())  # Weight is always 1 in this context
            donor_id = int(donor_id[1:])  # Remove prefix and convert to int
            patient_id = int(patient_id[:-1])  # Remove suffix and convert to int
            
            # Add arc info to the list
            arcs.append({
                'donor_id': donor_id,
                'patient_id': patient_id,
                'weight': weight,
            })
        
        # Store the arcs data in the dictionary
        data['arcs'] = arcs

    # Return the final structured dictionary
    return data


# Example usage of the function
#data = import_kidney_data(filepath)

# %%
def create_graph(data):
    """
    Creates a directed graph from the input data.

    Parameters:
    data (dict): A dictionary with two keys:
        - 'pairs': A list of dictionaries, each containing an 'id' for a node.
        - 'arcs': A list of dictionaries, each containing 'donor_id' (start node), 
                  'patient_id' (end node), and 'weight' (weight of the edge).

    Returns:
    G (nx.DiGraph): A directed graph created from the input data.
    """
    G = nx.DiGraph()
    
    # Add nodes to the graph from 'pairs' in data
    for pair in data['pairs']:
        G.add_node(pair['id'])
    
    # Add edges (directed) with weights from 'arcs' in data
    for arc in data['arcs']:
        G.add_edge(arc['donor_id'], arc['patient_id'], weight=arc['weight'])
    
    return G


def findPaths(G, u, n):
    """
    Recursively finds all paths of length n starting from node u.

    Parameters:
    G (nx.DiGraph): A directed graph.
    u (hashable): The starting node of the path.
    n (int): The length of the paths to find.

    Returns:
    paths (list): A list of all possible paths of length n starting from node u. 
                  Each path is represented as a list of nodes.
    """
    if n == 0:
        # Base case: if the path length is 0, return the starting node as the path
        return [[u]]
    
    # Recursive case: explore neighbors of the current node and find paths of length n-1
    paths = [[u] + path for neighbor in G.neighbors(u) for path in findPaths(G, neighbor, n-1)]
    
    return paths


def find_cycles(G, u, n):
    """
    Finds all cycles of length n starting and ending at node u.

    Parameters:
    G (nx.DiGraph): A directed graph.
    u (hashable): The node where the cycle starts and ends.
    n (int): The length of the cycle (number of edges in the cycle).

    Returns:
    cycles (list): A list of all cycles of length n starting and ending at node u.
                   Each cycle is represented as a tuple of nodes.
    """
    # Find all paths of length n starting from node u
    paths = findPaths(G, u, n)
    
    # Filter paths that form a cycle, meaning they end at u and visit u exactly twice
    return [tuple(path) for path in paths if (path[-1] == u) and sum(x == u for x in path) == 2]


def set_weight(dict_list, donor_id, patient_id, weight_key="weight"):
    """
    Retrieve the weight of an arc between a donor and a patient.

    Args:
        dict_list (list): List of dictionaries representing arcs.
        donor_id (int): The ID of the donor.
        patient_id (int): The ID of the patient.
        weight_key (str): The key to access the weight in the dictionary (default is "weight").

    Returns:
        int: The weight of the arc if found, otherwise None.
    """
    for dct in dict_list:
        if dct.get("donor_id") == donor_id and dct.get("patient_id") == patient_id:
            return dct.get(weight_key)
    return None  # Return None if no matching arc is found

# %%
def calculate_cycles_and_paths(G, data, k):
    """
    Calculates cycles and paths for a single value of k from the directed graph G.
    
    Parameters:
    G (nx.DiGraph): The directed graph.
    data (dict): The kidney exchange data.
    k (int): The maximum cycle length to process.

    Returns:
    c (list): A list of cycles.
    p (list): A list of paths.
    """
    c = []  # List to store information about cycles
    p = []  # List to store information about paths
    id_count = 0

    # Loop through possible cycle lengths from 1 to k-1 (cycle length)
    for l in range(2, k+1):
        for node in G.nodes:  # Iterate over all nodes in the graph
            for cyc in list(find_cycles(G, node, l)):  # Find all cycles starting at this node of length 'l'
                cyc_success = 0
                cyc_weight = 0
                # Calculate the success and weight for the cycle
                for n in range(1, len(cyc)):
                    cyc_success += data['pairs'][cyc[n]]['patient_vpra']  # Sum up the vPRA values of patients in the cycle
                    cyc_weight += set_weight(data['arcs'], cyc[n-1], cyc[n])  # Add the weight of the arc between consecutive pairs in the cycle
                # Append the cycle info to the list 'c'
                c.append({'id': id_count, 'cycle': cyc, 'vpra_sum': cyc_success, 'weight_sum': cyc_weight})  
                id_count += 1

    # Loop through possible path lengths from 1 to k-2 (since paths are from NDDs)
    for l in range(1, k-1):
        for node in G.nodes:  # Iterate over all nodes in the graph
            if data['pairs'][node]['is_ndd']:  # Only consider nodes that are NDDs
                for path in list(findPaths(G, node, l)):  # Find all paths starting at this NDD node of length 'l'
                    path_success = 0
                    path_weight = 0
                    # Calculate the success and weight for the path
                    for n in range(1, len(path)):
                        path_success += data['pairs'][path[n]]['patient_vpra']  # Sum up the vPRA values of patients in the path
                        path_weight += set_weight(data['arcs'], path[n-1], path[n])  # Add the weight of the arc between consecutive pairs in the path
                    # Append the path info to the list 'p'
                    p.append({'id': id_count, 'path': path, 'vpra_sum': path_success, 'weight_sum': path_weight}) 
                    id_count += 1

    # Return cycles and paths
    return c, p

# %% [markdown]
# # Implement branch and cut method

# %%
def solve_kidney_exchange(G, cycles, paths, k, time_limit=14400, mip_gap = 0.001):
    """
    Solves the kidney exchange problem using Gurobi's branch-and-bound algorithm.

    Parameters:
    G (nx.DiGraph): A directed graph representing the kidney exchange network.
    cycles (list of dicts): List of cycles, where each dict contains:
        - 'id': Unique ID for the cycle.
        - 'cycle': List of nodes in the cycle.
        - 'weight_sum': Sum of weights (or values) for the edges in the cycle.
    paths (list of dicts): List of paths (chains from NDD), where each dict contains:
        - 'id': Unique ID for the path.
        - 'path': List of nodes in the path.
        - 'weight_sum': Sum of weights (or values) for the edges in the path.
    k (int): The maximum allowed cycle length to process.
    time_limit (int): The time limit for solving the model (in seconds).
    mip_gap (float): The MIP optimality gap tolerance.

    Returns:
    dict: A summary of the solution, including selected cycles, paths, and optimization statistics.
    """

    # Start timer for performance tracking
    start_time = time.time()

    # Initialize the model
    model = gp.Model("KidneyExchange")

    # Step 1: Define Binary decision variables for cycles and paths
    cycle_vars = {cycle['id']: model.addVar(vtype=GRB.BINARY, name=f"cycle_{cycle['id']}") for cycle in cycles}
    path_vars = {path['id']: model.addVar(vtype=GRB.BINARY, name=f"path_{path['id']}") for path in paths}

    # Step 2: Set objective function to maximize total weight of selected cycles and paths
    obj = gp.LinExpr()

    for cycle in cycles:
        obj += cycle['weight_sum'] * cycle_vars[cycle['id']]
    
    for path in paths:
        obj += path['weight_sum'] * path_vars[path['id']]

    model.setObjective(obj, GRB.MAXIMIZE)

    # Step 3: Add constraints to ensure each vertex (pair or NDD) is in at most one cycle or path
    for node in G.nodes:
        constraint = gp.LinExpr()

        # Add constraints for cycles
        for cycle in cycles:
            if node in cycle['cycle']:
                constraint += cycle_vars[cycle['id']]

        # Add constraints for paths
        for path in paths:
            if node in path['path']:
                constraint += path_vars[path['id']]

        # Ensure each node is used at most once
        model.addConstr(constraint <= 1, name=f"vertex_disjoint_{node}")

    # Step 4: Add a constraint to limit cycle sizes based on the value of k
    for cycle in cycles:
        if len(cycle['cycle']) > k:
            model.addConstr(cycle_vars[cycle['id']] == 0, name=f"max_cycle_size_{cycle['id']}")

    # Step 5: Set solver parameters
    model.Params.TimeLimit = time_limit  # Set a time limit (in seconds)
    model.Params.MIPGap = mip_gap       # Set a MIP optimality gap tolerance

    # Solve the model
    model.optimize()

    # Initialize solution dictionary
    solution = {
        'total_score': 0,
        'selected_cycles': [],
        'selected_paths': [],
        'optimization_info': {}
    }

    # Check if the model has found an optimal or feasible solution
    if model.status in [GRB.OPTIMAL, GRB.TIME_LIMIT]:
        if model.status == GRB.OPTIMAL:
            print("Optimal solution found!")
        elif model.status == GRB.TIME_LIMIT:
            print("Time limit reached. Returning best feasible solution found.")

        total_score = 0

        # Extract selected cycles
        for cycle in cycles:
            if round(cycle_vars[cycle['id']].x) > 0.5:  # Cycle selected
                cycle_type = "Cycle"
                cycle_size = len(cycle['cycle'])  # Size of the cycle (number of nodes)
                cycle_nodes = cycle['cycle']  # Nodes in the cycle
                cycle_score = cycle['weight_sum']  # Total score for the cycle
                total_score += cycle_score

                # Store cycle details in the solution
                solution['selected_cycles'].append({
                    'type': cycle_type,
                    'size': cycle_size,
                    'nodes': cycle_nodes,
                    'score': cycle_score
                })

        # Extract selected paths (chains)
        for path in paths:
            if round(path_vars[path['id']].x) > 0.5:  # Path selected
                path_type = "Chain"
                path_size = len(path['path'])  # Size of the path (number of nodes)
                path_nodes = path['path']  # Nodes in the path
                path_score = path['weight_sum']  # Total score for the path
                total_score += path_score

                # Store path details in the solution
                solution['selected_paths'].append({
                    'type': path_type,
                    'size': path_size,
                    'nodes': path_nodes,
                    'score': path_score
                })

        solution['total_score'] = total_score

        # Capture optimization statistics
        total_time = time.time() - start_time
        solution['optimization_info'] = {
            'optimal_solution_found': model.status == GRB.OPTIMAL,
            'total_time_s': total_time,
            'number_of_variables': model.NumVars,
            'number_of_constraints': model.NumConstrs,
            'number_of_non_zeros': model.NumNZs,
            'objective_1_max_cycles_and_chains': len(solution['selected_cycles']) + len(solution['selected_paths']),
            'objective_2_min_cycles_and_chains_of_size_4': len([x for x in solution['selected_cycles'] if len(x['nodes']) == 4]),
            'objective_3_min_cycles_chains_of_size_3': len([x for x in solution['selected_cycles'] if len(x['nodes']) == 3]),
            'objective_4_max_total_score_weight': total_score
        }
    else:
        print(f"No optimal or feasible solution found. Status: {model.status}")

    return solution

# %% [markdown]
# # Process and save multiple optimization processes in one run

# %%
def save_solution(filepath, solution, output_folder, k):
    """
    Saves the solution of each file in the output folder, including optimization info and transplant count.
    
    Args:
        filepath (str): The path to the text file containing the kidney exchange data.
        solution (dict): The solution data to be saved.
        output_folder (str): The path to the folder where solutions should be saved.
        k (int): The value of k (cycle length) to append to the solution file name.
    """
    # Step 1: Extract the filename without the extension
    filename = os.path.basename(filepath)
    file_base_name = os.path.splitext(filename)[0]

    # Step 2: Create the solution file path inside the output folder, with k in the filename
    solution_file_path = os.path.join(output_folder, f"{file_base_name}_solution_k{k-1}.txt")
    
    # Step 3: Calculate the total number of transplants (i.e., the number of unique nodes in cycles and paths)
    total_transplants = sum([len(set(cycle['nodes'])) for cycle in solution['selected_cycles']]) + \
                        sum([path['size'] for path in solution['selected_paths']])
    
    # Step 4: Save the solution in the file
    with open(solution_file_path, 'w') as f:
        f.write(f"Running with k = {k-1}:\n\n")  # Add k to the output file
        
        f.write("Selected Cycles:\n")
        for idx, cycle in enumerate(solution['selected_cycles']):
            unique_cycle_size = len(set(cycle['nodes']))  # Count unique nodes
            
            f.write(f"{idx + 1}:\n")
            f.write(f"Type: {cycle['type']}\n")
            f.write(f"Size: {unique_cycle_size}\n")  # Use the unique cycle size
            f.write(f"Nodes: {', '.join(map(str, cycle['nodes']))}\n")
            f.write(f"Score: {cycle['score']}\n")
            f.write("-------------------------------------------\n")
        
        f.write("\nSelected Paths:\n")
        for idx, path in enumerate(solution['selected_paths']):
            f.write(f"{idx + 1}:\n")
            f.write(f"Type: {path['type']}\n")
            f.write(f"Size: {path['size']}\n")
            f.write(f"Nodes: {', '.join(map(str, path['nodes']))}\n")
            f.write(f"Score: {path['score']}\n")
            f.write("-------------------------------------------\n")
        
        # Step 5: Add the total score and transplants to the file
        f.write(f"Total score: {solution['total_score']}\n")
        f.write(f"Number of transplants: {total_transplants}\n")  # Add the number of transplants
        
        # Step 6: Add optimization information
        f.write("\nOptimization information:\n")
        for key, value in solution['optimization_info'].items():
            f.write(f"{key}: {value}\n")
    
    print(f"Solution saved for k = {k} in {solution_file_path}")

# %%
import re

# Helper function for natural sorting
def natural_key(string):
    """Helper function to sort strings containing numbers in human order."""
    return [int(text) if text.isdigit() else text.lower() for text in re.split('([0-9]+)', string)]

def process_files(directory, output_folder, k_values):
    """
    Processes all relevant files in the directory, computes solutions for multiple k values, and saves them in the output folder.
    
    Args:
        directory (str): The directory containing the input files.
        output_folder (str): The directory where the solutions should be saved.
        k_values (list): A list of k values to process.
    """
    prefixes = ["RandomSparse", "Delorme", "Saidman"]
    
    # List of specific files to process for k == 6
    files_for_k6 = [
        "Delorme_50_NDD_Weight_0.txt", "Delorme_200_NDD_Weight_0.txt", 
        "Saidman_50_NDD_Weight_0.txt", "Saidman_200_NDD_Weight_0.txt", 
        "RandomSparse_200_NDD_Weight_0.txt"
    ]
    
    # Fetch all files that match the prefixes and have .txt extension (no sorting)
    files = [f for f in os.listdir(directory) if any(f.startswith(prefix) for prefix in prefixes) and f.endswith('.txt')]
    
    # Apply natural sorting to the file list
    files.sort(key=natural_key)
    
    print("Files to process:", files)  # Debug print to check the order of files

    for file in files:
        filepath = os.path.join(directory, file)
        
        # Loop through each value of k and process the solutions
        for k in k_values:
            # Check if k is 6, then only process specific files
            if k == 6:
                if file not in files_for_k6:
                    print(f"Skipping file {file} for k = {k}")
                    continue  # Skip files that are not in the allowed list for k = 6
            
            print(f"Calculating cycles and paths for k = {k}, file: {file}")
            
            # Import the kidney exchange data from the file
            data = import_kidney_data(filepath)
            
            # Create a directed graph from the data
            G = create_graph(data)
            
            # Calculate cycles and paths for the current k
            cycles, paths = calculate_cycles_and_paths(G, data, k)
            
            # Solve the kidney exchange problem
            solution = solve_kidney_exchange(G, cycles, paths, k)
            
            # Save the solution for the current k
            save_solution(filepath, solution, output_folder, k)
            print(f"Results saved for k = {k}, file: {file}\n")


# Define your input directory and the output folder - change the paths as needed
input_directory = "/Users/Martijn/Downloads/KidneyExchangeOptimization/test"
output_folder = "/Users/Martijn/Downloads/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound"

# Example usage
k_values = [4,5,6]
process_files(input_directory, output_folder, k_values)
# Out:
# Files to process: ['Delorme_500_NDD_Weight_0.txt']
# Calculating cycles and paths for k = 4, file: Delorme_500_NDD_Weight_0.txt
# time.struct_time(tm_year=2024, tm_mon=10, tm_mday=14, tm_hour=16, tm_min=32, tm_sec=59, tm_wday=0, tm_yday=288, tm_isdst=1)
# Cycles and paths processed. Starting optimization...
# time.struct_time(tm_year=2024, tm_mon=10, tm_mday=14, tm_hour=16, tm_min=39, tm_sec=20, tm_wday=0, tm_yday=288, tm_isdst=1)
# {'id': 127844, 'path': [475, 4], 'vpra_sum': 0, 'weight_sum': 75}
# {'id': 127845, 'path': [475, 8], 'vpra_sum': 0, 'weight_sum': 10}
# {'id': 127846, 'path': [475, 14], 'vpra_sum': 0, 'weight_sum': 41}
# {'id': 127847, 'path': [475, 16], 'vpra_sum': 1, 'weight_sum': 68}
# {'id': 127848, 'path': [475, 19], 'vpra_sum': 0, 'weight_sum': 5}
# {'id': 127849, 'path': [475, 21], 'vpra_sum': 0, 'weight_sum': 4}
# {'id': 127850, 'path': [475, 22], 'vpra_sum': 1, 'weight_sum': 41}
# {'id': 127851, 'path': [475, 35], 'vpra_sum': 0, 'weight_sum': 79}
# {'id': 127852, 'path': [475, 36], 'vpra_sum': 0, 'weight_sum': 86}
# {'id': 127853, 'path': [475, 49], 'vpra_sum': 2, 'weight_sum': 20}
# {'id': 127854, 'path': [475, 50], 'vpra_sum': 0, 'weight_sum': 0}
# {'id': 127855, 'path': [475, 57], 'vpra_sum': 0, 'weight_sum': 69}
# {'id': 127856, 'path': [475, 62], 'vpra_sum': 0, 'weight_sum': 57}
# {'id': 127857, 'path': [475, 63], 'vpra_sum': 0, 'weight_sum': 43}
# {'id': 127858, 'path': [475, 66], 'vpra_sum': 0, 'weight_sum': 82}
# {'id': 127859, 'path': [475, 78], 'vpra_sum': 0, 'weight_sum': 66}
# {'id': 127860, 'path': [475, 80], 'vpra_sum': 1, 'weight_sum': 18}
# {'id': 127861, 'path': [475, 88], 'vpra_sum': 0, 'weight_sum': 42}
# {'id': 127862, 'path': [475, 93], 'vpra_sum': 0, 'weight_sum': 26}
# {'id': 127863, 'path': [475, 94], 'vpra_sum': 0, 'weight_sum': 86}
# {'id': 127864, 'path': [475, 99], 'vpra_sum': 0, 'weight_sum': 81}
# {'id': 127865, 'path': [475, 115], 'vpra_sum': 0, 'weight_sum': 66}
# {'id': 127866, 'path': [475, 118], 'vpra_sum': 0, 'weight_sum': 46}
# {'id': 127867, 'path': [475, 119], 'vpra_sum': 0, 'weight_sum': 19}
# {'id': 127868, 'path': [475, 136], 'vpra_sum': 0, 'weight_sum': 17}
# {'id': 127869, 'path': [475, 144], 'vpra_sum': 0, 'weight_sum': 38}
# {'id': 127870, 'path': [475, 148], 'vpra_sum': 0, 'weight_sum': 8}
# {'id': 127871, 'path': [475, 150], 'vpra_sum': 0, 'weight_sum': 58}
# {'id': 127872, 'path': [475, 163], 'vpra_sum': 0, 'weight_sum': 73}
# {'id': 127873, 'path': [475, 164], 'vpra_sum': 0, 'weight_sum': 3}
# {'id': 127874, 'path': [475, 166], 'vpra_sum': 0, 'weight_sum': 0}
# {'id': 127875, 'path': [475, 168], 'vpra_sum': 0, 'weight_sum': 75}
# {'id': 127876, 'path': [475, 186], 'vpra_sum': 0, 'weight_sum': 40}
# {'id': 127877, 'path': [475, 189], 'vpra_sum': 0, 'weight_sum': 65}
# {'id': 127878, 'path': [475, 190], 'vpra_sum': 0, 'weight_sum': 22}
# {'id': 127879, 'path': [475, 191], 'vpra_sum': 0, 'weight_sum': 41}
# {'id': 127880, 'path': [475, 192], 'vpra_sum': 0, 'weight_sum': 32}
# {'id': 127881, 'path': [475, 219], 'vpra_sum': 0, 'weight_sum': 86}
# {'id': 127882, 'path': [475, 223], 'vpra_sum': 0, 'weight_sum': 14}
# {'id': 127883, 'path': [475, 225], 'vpra_sum': 0, 'weight_sum': 77}
# {'id': 127884, 'path': [475, 226], 'vpra_sum': 0, 'weight_sum': 56}
# {'id': 127885, 'path': [475, 229], 'vpra_sum': 0, 'weight_sum': 0}
# {'id': 127886, 'path': [475, 239], 'vpra_sum': 0, 'weight_sum': 43}
# {'id': 127887, 'path': [475, 241], 'vpra_sum': 0, 'weight_sum': 35}
# {'id': 127888, 'path': [475, 242], 'vpra_sum': 0, 'weight_sum': 64}
# {'id': 127889, 'path': [475, 243], 'vpra_sum': 0, 'weight_sum': 44}
# {'id': 127890, 'path': [475, 244], 'vpra_sum': 0, 'weight_sum': 9}
# {'id': 127891, 'path': [475, 246], 'vpra_sum': 2, 'weight_sum': 87}
# {'id': 127892, 'path': [475, 247], 'vpra_sum': 0, 'weight_sum': 54}
# {'id': 127893, 'path': [475, 249], 'vpra_sum': 2, 'weight_sum': 23}
# {'id': 127894, 'path': [475, 255], 'vpra_sum': 1, 'weight_sum': 18}
# {'id': 127895, 'path': [475, 259], 'vpra_sum': 0, 'weight_sum': 21}
# {'id': 127896, 'path': [475, 260], 'vpra_sum': 2, 'weight_sum': 87}
# {'id': 127897, 'path': [475, 264], 'vpra_sum': 0, 'weight_sum': 70}
# {'id': 127898, 'path': [475, 269], 'vpra_sum': 0, 'weight_sum': 66}
# {'id': 127899, 'path': [475, 272], 'vpra_sum': 2, 'weight_sum': 50}
# {'id': 127900, 'path': [475, 273], 'vpra_sum': 0, 'weight_sum': 30}
# {'id': 127901, 'path': [475, 277], 'vpra_sum': 0, 'weight_sum': 69}
# {'id': 127902, 'path': [475, 278], 'vpra_sum': 0, 'weight_sum': 62}
# {'id': 127903, 'path': [475, 282], 'vpra_sum': 0, 'weight_sum': 7}
# {'id': 127904, 'path': [475, 283], 'vpra_sum': 1, 'weight_sum': 55}
# {'id': 127905, 'path': [475, 284], 'vpra_sum': 0, 'weight_sum': 33}
# {'id': 127906, 'path': [475, 294], 'vpra_sum': 0, 'weight_sum': 38}
# {'id': 127907, 'path': [475, 297], 'vpra_sum': 1, 'weight_sum': 68}
# {'id': 127908, 'path': [475, 300], 'vpra_sum': 0, 'weight_sum': 60}
# {'id': 127909, 'path': [475, 303], 'vpra_sum': 0, 'weight_sum': 61}
# {'id': 127910, 'path': [475, 308], 'vpra_sum': 0, 'weight_sum': 70}
# {'id': 127911, 'path': [475, 311], 'vpra_sum': 1, 'weight_sum': 20}
# {'id': 127912, 'path': [475, 317], 'vpra_sum': 0, 'weight_sum': 35}
# {'id': 127913, 'path': [475, 320], 'vpra_sum': 0, 'weight_sum': 42}
# {'id': 127914, 'path': [475, 322], 'vpra_sum': 0, 'weight_sum': 57}
# {'id': 127915, 'path': [475, 328], 'vpra_sum': 0, 'weight_sum': 45}
# {'id': 127916, 'path': [475, 329], 'vpra_sum': 1, 'weight_sum': 0}
# {'id': 127917, 'path': [475, 331], 'vpra_sum': 0, 'weight_sum': 19}
# {'id': 127918, 'path': [475, 339], 'vpra_sum': 0, 'weight_sum': 83}
# {'id': 127919, 'path': [475, 341], 'vpra_sum': 0, 'weight_sum': 56}
# {'id': 127920, 'path': [475, 348], 'vpra_sum': 1, 'weight_sum': 69}
# {'id': 127921, 'path': [475, 349], 'vpra_sum': 0, 'weight_sum': 40}
# {'id': 127922, 'path': [475, 351], 'vpra_sum': 0, 'weight_sum': 13}
# {'id': 127923, 'path': [475, 354], 'vpra_sum': 0, 'weight_sum': 19}
# {'id': 127924, 'path': [475, 356], 'vpra_sum': 0, 'weight_sum': 15}
# {'id': 127925, 'path': [475, 363], 'vpra_sum': 0, 'weight_sum': 83}
# {'id': 127926, 'path': [475, 365], 'vpra_sum': 0, 'weight_sum': 81}
# {'id': 127927, 'path': [475, 366], 'vpra_sum': 0, 'weight_sum': 24}
# {'id': 127928, 'path': [475, 370], 'vpra_sum': 0, 'weight_sum': 61}
# {'id': 127929, 'path': [475, 373], 'vpra_sum': 0, 'weight_sum': 44}
# {'id': 127930, 'path': [475, 374], 'vpra_sum': 0, 'weight_sum': 81}
# {'id': 127931, 'path': [475, 377], 'vpra_sum': 0, 'weight_sum': 52}
# {'id': 127932, 'path': [475, 394], 'vpra_sum': 1, 'weight_sum': 17}
# {'id': 127933, 'path': [475, 397], 'vpra_sum': 0, 'weight_sum': 26}
# {'id': 127934, 'path': [475, 399], 'vpra_sum': 2, 'weight_sum': 79}
# {'id': 127935, 'path': [475, 400], 'vpra_sum': 1, 'weight_sum': 30}
# {'id': 127936, 'path': [475, 402], 'vpra_sum': 0, 'weight_sum': 55}
# {'id': 127937, 'path': [475, 404], 'vpra_sum': 0, 'weight_sum': 66}
# {'id': 127938, 'path': [475, 405], 'vpra_sum': 1, 'weight_sum': 44}
# {'id': 127939, 'path': [475, 410], 'vpra_sum': 0, 'weight_sum': 13}
# {'id': 127940, 'path': [475, 412], 'vpra_sum': 0, 'weight_sum': 7}
# {'id': 127941, 'path': [475, 413], 'vpra_sum': 0, 'weight_sum': 63}
# {'id': 127942, 'path': [475, 420], 'vpra_sum': 0, 'weight_sum': 85}
# {'id': 127943, 'path': [475, 421], 'vpra_sum': 0, 'weight_sum': 21}
# {'id': 127944, 'path': [475, 422], 'vpra_sum': 0, 'weight_sum': 80}
# {'id': 127945, 'path': [475, 423], 'vpra_sum': 0, 'weight_sum': 58}
# {'id': 127946, 'path': [475, 424], 'vpra_sum': 2, 'weight_sum': 59}
# {'id': 127947, 'path': [475, 427], 'vpra_sum': 0, 'weight_sum': 85}
# {'id': 127948, 'path': [475, 431], 'vpra_sum': 2, 'weight_sum': 37}
# {'id': 127949, 'path': [475, 439], 'vpra_sum': 0, 'weight_sum': 69}
# {'id': 127950, 'path': [475, 445], 'vpra_sum': 0, 'weight_sum': 35}
# {'id': 127951, 'path': [475, 449], 'vpra_sum': 0, 'weight_sum': 71}
# {'id': 127952, 'path': [475, 457], 'vpra_sum': 0, 'weight_sum': 22}
# {'id': 127953, 'path': [475, 458], 'vpra_sum': 0, 'weight_sum': 76}
# {'id': 127954, 'path': [475, 461], 'vpra_sum': 0, 'weight_sum': 76}
# {'id': 127955, 'path': [475, 468], 'vpra_sum': 0, 'weight_sum': 59}
# {'id': 127956, 'path': [475, 471], 'vpra_sum': 0, 'weight_sum': 39}
# {'id': 127957, 'path': [475, 472], 'vpra_sum': 0, 'weight_sum': 37}
# {'id': 127958, 'path': [476, 5], 'vpra_sum': 1, 'weight_sum': 78}
# {'id': 127959, 'path': [476, 8], 'vpra_sum': 0, 'weight_sum': 28}
# {'id': 127960, 'path': [476, 12], 'vpra_sum': 1, 'weight_sum': 46}
# {'id': 127961, 'path': [476, 14], 'vpra_sum': 0, 'weight_sum': 68}
# {'id': 127962, 'path': [476, 15], 'vpra_sum': 1, 'weight_sum': 79}
# {'id': 127963, 'path': [476, 16], 'vpra_sum': 1, 'weight_sum': 70}
# {'id': 127964, 'path': [476, 18], 'vpra_sum': 2, 'weight_sum': 42}
# {'id': 127965, 'path': [476, 19], 'vpra_sum': 0, 'weight_sum': 41}
# {'id': 127966, 'path': [476, 21], 'vpra_sum': 0, 'weight_sum': 57}
# {'id': 127967, 'path': [476, 24], 'vpra_sum': 0, 'weight_sum': 24}
# {'id': 127968, 'path': [476, 31], 'vpra_sum': 1, 'weight_sum': 45}
# {'id': 127969, 'path': [476, 35], 'vpra_sum': 0, 'weight_sum': 61}
# {'id': 127970, 'path': [476, 36], 'vpra_sum': 0, 'weight_sum': 3}
# {'id': 127971, 'path': [476, 50], 'vpra_sum': 0, 'weight_sum': 27}
# {'id': 127972, 'path': [476, 57], 'vpra_sum': 0, 'weight_sum': 52}
# {'id': 127973, 'path': [476, 62], 'vpra_sum': 0, 'weight_sum': 55}
# {'id': 127974, 'path': [476, 63], 'vpra_sum': 0, 'weight_sum': 55}
# {'id': 127975, 'path': [476, 67], 'vpra_sum': 1, 'weight_sum': 14}
# {'id': 127976, 'path': [476, 78], 'vpra_sum': 0, 'weight_sum': 41}
# {'id': 127977, 'path': [476, 79], 'vpra_sum': 1, 'weight_sum': 64}
# {'id': 127978, 'path': [476, 93], 'vpra_sum': 0, 'weight_sum': 56}
# {'id': 127979, 'path': [476, 94], 'vpra_sum': 0, 'weight_sum': 11}
# {'id': 127980, 'path': [476, 97], 'vpra_sum': 2, 'weight_sum': 80}
# {'id': 127981, 'path': [476, 99], 'vpra_sum': 0, 'weight_sum': 85}
# {'id': 127982, 'path': [476, 115], 'vpra_sum': 0, 'weight_sum': 9}
# {'id': 127983, 'path': [476, 119], 'vpra_sum': 0, 'weight_sum': 20}
# {'id': 127984, 'path': [476, 126], 'vpra_sum': 2, 'weight_sum': 14}
# {'id': 127985, 'path': [476, 128], 'vpra_sum': 1, 'weight_sum': 15}
# {'id': 127986, 'path': [476, 136], 'vpra_sum': 0, 'weight_sum': 66}
# {'id': 127987, 'path': [476, 138], 'vpra_sum': 1, 'weight_sum': 25}
# {'id': 127988, 'path': [476, 144], 'vpra_sum': 0, 'weight_sum': 80}
# {'id': 127989, 'path': [476, 148], 'vpra_sum': 0, 'weight_sum': 36}
# {'id': 127990, 'path': [476, 152], 'vpra_sum': 1, 'weight_sum': 48}
# {'id': 127991, 'path': [476, 163], 'vpra_sum': 0, 'weight_sum': 72}
# {'id': 127992, 'path': [476, 164], 'vpra_sum': 0, 'weight_sum': 13}
# {'id': 127993, 'path': [476, 166], 'vpra_sum': 0, 'weight_sum': 22}
# {'id': 127994, 'path': [476, 168], 'vpra_sum': 0, 'weight_sum': 70}
# {'id': 127995, 'path': [476, 183], 'vpra_sum': 2, 'weight_sum': 70}
# {'id': 127996, 'path': [476, 185], 'vpra_sum': 2, 'weight_sum': 57}
# {'id': 127997, 'path': [476, 186], 'vpra_sum': 0, 'weight_sum': 46}
# {'id': 127998, 'path': [476, 189], 'vpra_sum': 0, 'weight_sum': 65}
# {'id': 127999, 'path': [476, 190], 'vpra_sum': 0, 'weight_sum': 44}
# {'id': 128000, 'path': [476, 191], 'vpra_sum': 0, 'weight_sum': 74}
# {'id': 128001, 'path': [476, 192], 'vpra_sum': 0, 'weight_sum': 26}
# {'id': 128002, 'path': [476, 199], 'vpra_sum': 2, 'weight_sum': 63}
# {'id': 128003, 'path': [476, 219], 'vpra_sum': 0, 'weight_sum': 52}
# {'id': 128004, 'path': [476, 223], 'vpra_sum': 0, 'weight_sum': 41}
# {'id': 128005, 'path': [476, 225], 'vpra_sum': 0, 'weight_sum': 53}
# {'id': 128006, 'path': [476, 226], 'vpra_sum': 0, 'weight_sum': 63}
# {'id': 128007, 'path': [476, 229], 'vpra_sum': 0, 'weight_sum': 11}
# {'id': 128008, 'path': [476, 239], 'vpra_sum': 0, 'weight_sum': 7}
# {'id': 128009, 'path': [476, 241], 'vpra_sum': 0, 'weight_sum': 19}
# {'id': 128010, 'path': [476, 242], 'vpra_sum': 0, 'weight_sum': 20}
# {'id': 128011, 'path': [476, 243], 'vpra_sum': 0, 'weight_sum': 14}
# {'id': 128012, 'path': [476, 244], 'vpra_sum': 0, 'weight_sum': 5}
# {'id': 128013, 'path': [476, 247], 'vpra_sum': 0, 'weight_sum': 15}
# {'id': 128014, 'path': [476, 264], 'vpra_sum': 0, 'weight_sum': 10}
# {'id': 128015, 'path': [476, 268], 'vpra_sum': 0, 'weight_sum': 42}
# {'id': 128016, 'path': [476, 269], 'vpra_sum': 0, 'weight_sum': 24}
# {'id': 128017, 'path': [476, 276], 'vpra_sum': 0, 'weight_sum': 0}
# {'id': 128018, 'path': [476, 277], 'vpra_sum': 0, 'weight_sum': 20}
# {'id': 128019, 'path': [476, 278], 'vpra_sum': 0, 'weight_sum': 76}
# {'id': 128020, 'path': [476, 282], 'vpra_sum': 0, 'weight_sum': 10}
# {'id': 128021, 'path': [476, 294], 'vpra_sum': 0, 'weight_sum': 27}
# {'id': 128022, 'path': [476, 297], 'vpra_sum': 1, 'weight_sum': 89}
# {'id': 128023, 'path': [476, 300], 'vpra_sum': 0, 'weight_sum': 68}
# {'id': 128024, 'path': [476, 303], 'vpra_sum': 0, 'weight_sum': 61}
# {'id': 128025, 'path': [476, 308], 'vpra_sum': 0, 'weight_sum': 80}
# {'id': 128026, 'path': [476, 311], 'vpra_sum': 1, 'weight_sum': 21}
# {'id': 128027, 'path': [476, 317], 'vpra_sum': 0, 'weight_sum': 71}
# {'id': 128028, 'path': [476, 320], 'vpra_sum': 0, 'weight_sum': 86}
# {'id': 128029, 'path': [476, 321], 'vpra_sum': 1, 'weight_sum': 68}
# {'id': 128030, 'path': [476, 322], 'vpra_sum': 0, 'weight_sum': 86}
# {'id': 128031, 'path': [476, 323], 'vpra_sum': 0, 'weight_sum': 58}
# {'id': 128032, 'path': [476, 325], 'vpra_sum': 0, 'weight_sum': 51}
# {'id': 128033, 'path': [476, 328], 'vpra_sum': 0, 'weight_sum': 78}
# {'id': 128034, 'path': [476, 331], 'vpra_sum': 0, 'weight_sum': 82}
# {'id': 128035, 'path': [476, 335], 'vpra_sum': 0, 'weight_sum': 65}
# {'id': 128036, 'path': [476, 341], 'vpra_sum': 0, 'weight_sum': 21}
# {'id': 128037, 'path': [476, 343], 'vpra_sum': 2, 'weight_sum': 53}
# {'id': 128038, 'path': [476, 344], 'vpra_sum': 2, 'weight_sum': 72}
# {'id': 128039, 'path': [476, 349], 'vpra_sum': 0, 'weight_sum': 12}
# {'id': 128040, 'path': [476, 351], 'vpra_sum': 0, 'weight_sum': 77}
# {'id': 128041, 'path': [476, 354], 'vpra_sum': 0, 'weight_sum': 80}
# {'id': 128042, 'path': [476, 356], 'vpra_sum': 0, 'weight_sum': 64}
# {'id': 128043, 'path': [476, 363], 'vpra_sum': 0, 'weight_sum': 63}
# {'id': 128044, 'path': [476, 365], 'vpra_sum': 0, 'weight_sum': 37}
# {'id': 128045, 'path': [476, 366], 'vpra_sum': 0, 'weight_sum': 49}
# {'id': 128046, 'path': [476, 370], 'vpra_sum': 0, 'weight_sum': 27}
# {'id': 128047, 'path': [476, 373], 'vpra_sum': 0, 'weight_sum': 84}
# {'id': 128048, 'path': [476, 374], 'vpra_sum': 0, 'weight_sum': 60}
# {'id': 128049, 'path': [476, 376], 'vpra_sum': 1, 'weight_sum': 32}
# {'id': 128050, 'path': [476, 377], 'vpra_sum': 0, 'weight_sum': 20}
# {'id': 128051, 'path': [476, 393], 'vpra_sum': 1, 'weight_sum': 24}
# {'id': 128052, 'path': [476, 397], 'vpra_sum': 0, 'weight_sum': 59}
# {'id': 128053, 'path': [476, 400], 'vpra_sum': 1, 'weight_sum': 15}
# {'id': 128054, 'path': [476, 401], 'vpra_sum': 1, 'weight_sum': 67}
# {'id': 128055, 'path': [476, 402], 'vpra_sum': 0, 'weight_sum': 36}
# {'id': 128056, 'path': [476, 404], 'vpra_sum': 0, 'weight_sum': 15}
# {'id': 128057, 'path': [476, 405], 'vpra_sum': 1, 'weight_sum': 29}
# {'id': 128058, 'path': [476, 410], 'vpra_sum': 0, 'weight_sum': 62}
# {'id': 128059, 'path': [476, 411], 'vpra_sum': 0, 'weight_sum': 86}
# {'id': 128060, 'path': [476, 412], 'vpra_sum': 0, 'weight_sum': 42}
# {'id': 128061, 'path': [476, 413], 'vpra_sum': 0, 'weight_sum': 13}
# {'id': 128062, 'path': [476, 420], 'vpra_sum': 0, 'weight_sum': 58}
# {'id': 128063, 'path': [476, 421], 'vpra_sum': 0, 'weight_sum': 29}
# {'id': 128064, 'path': [476, 422], 'vpra_sum': 0, 'weight_sum': 63}
# {'id': 128065, 'path': [476, 425], 'vpra_sum': 1, 'weight_sum': 75}
# {'id': 128066, 'path': [476, 427], 'vpra_sum': 0, 'weight_sum': 64}
# {'id': 128067, 'path': [476, 429], 'vpra_sum': 0, 'weight_sum': 17}
# {'id': 128068, 'path': [476, 431], 'vpra_sum': 2, 'weight_sum': 4}
# {'id': 128069, 'path': [476, 435], 'vpra_sum': 1, 'weight_sum': 45}
# {'id': 128070, 'path': [476, 439], 'vpra_sum': 0, 'weight_sum': 63}
# {'id': 128071, 'path': [476, 442], 'vpra_sum': 0, 'weight_sum': 46}
# {'id': 128072, 'path': [476, 454], 'vpra_sum': 2, 'weight_sum': 11}
# {'id': 128073, 'path': [476, 458], 'vpra_sum': 0, 'weight_sum': 49}
# {'id': 128074, 'path': [476, 461], 'vpra_sum': 0, 'weight_sum': 78}
# {'id': 128075, 'path': [476, 468], 'vpra_sum': 0, 'weight_sum': 79}
# {'id': 128076, 'path': [476, 471], 'vpra_sum': 0, 'weight_sum': 51}
# {'id': 128077, 'path': [477, 5], 'vpra_sum': 1, 'weight_sum': 23}
# {'id': 128078, 'path': [477, 8], 'vpra_sum': 0, 'weight_sum': 15}
# {'id': 128079, 'path': [477, 12], 'vpra_sum': 1, 'weight_sum': 16}
# {'id': 128080, 'path': [477, 18], 'vpra_sum': 2, 'weight_sum': 52}
# {'id': 128081, 'path': [477, 19], 'vpra_sum': 0, 'weight_sum': 5}
# {'id': 128082, 'path': [477, 21], 'vpra_sum': 0, 'weight_sum': 35}
# {'id': 128083, 'path': [477, 31], 'vpra_sum': 1, 'weight_sum': 34}
# {'id': 128084, 'path': [477, 35], 'vpra_sum': 0, 'weight_sum': 9}
# {'id': 128085, 'path': [477, 36], 'vpra_sum': 0, 'weight_sum': 89}
# {'id': 128086, 'path': [477, 50], 'vpra_sum': 0, 'weight_sum': 62}
# {'id': 128087, 'path': [477, 52], 'vpra_sum': 1, 'weight_sum': 89}
# {'id': 128088, 'path': [477, 56], 'vpra_sum': 1, 'weight_sum': 76}
# {'id': 128089, 'path': [477, 57], 'vpra_sum': 0, 'weight_sum': 51}
# {'id': 128090, 'path': [477, 62], 'vpra_sum': 0, 'weight_sum': 3}
# {'id': 128091, 'path': [477, 63], 'vpra_sum': 0, 'weight_sum': 68}
# {'id': 128092, 'path': [477, 78], 'vpra_sum': 0, 'weight_sum': 23}
# {'id': 128093, 'path': [477, 80], 'vpra_sum': 1, 'weight_sum': 74}
# {'id': 128094, 'path': [477, 81], 'vpra_sum': 2, 'weight_sum': 34}
# {'id': 128095, 'path': [477, 85], 'vpra_sum': 2, 'weight_sum': 42}
# {'id': 128096, 'path': [477, 88], 'vpra_sum': 0, 'weight_sum': 0}
# {'id': 128097, 'path': [477, 93], 'vpra_sum': 0, 'weight_sum': 88}
# {'id': 128098, 'path': [477, 94], 'vpra_sum': 0, 'weight_sum': 56}
# {'id': 128099, 'path': [477, 97], 'vpra_sum': 2, 'weight_sum': 29}
# {'id': 128100, 'path': [477, 99], 'vpra_sum': 0, 'weight_sum': 33}
# {'id': 128101, 'path': [477, 115], 'vpra_sum': 0, 'weight_sum': 18}
# {'id': 128102, 'path': [477, 118], 'vpra_sum': 0, 'weight_sum': 70}
# {'id': 128103, 'path': [477, 122], 'vpra_sum': 2, 'weight_sum': 58}
# {'id': 128104, 'path': [477, 136], 'vpra_sum': 0, 'weight_sum': 0}
# {'id': 128105, 'path': [477, 144], 'vpra_sum': 0, 'weight_sum': 21}
# {'id': 128106, 'path': [477, 148], 'vpra_sum': 0, 'weight_sum': 47}
# {'id': 128107, 'path': [477, 150], 'vpra_sum': 0, 'weight_sum': 72}
# {'id': 128108, 'path': [477, 163], 'vpra_sum': 0, 'weight_sum': 78}
# {'id': 128109, 'path': [477, 164], 'vpra_sum': 0, 'weight_sum': 85}
# {'id': 128110, 'path': [477, 166], 'vpra_sum': 0, 'weight_sum': 29}
# {'id': 128111, 'path': [477, 168], 'vpra_sum': 0, 'weight_sum': 77}
# {'id': 128112, 'path': [477, 171], 'vpra_sum': 1, 'weight_sum': 34}
# {'id': 128113, 'path': [477, 186], 'vpra_sum': 0, 'weight_sum': 55}
# {'id': 128114, 'path': [477, 189], 'vpra_sum': 0, 'weight_sum': 14}
# {'id': 128115, 'path': [477, 190], 'vpra_sum': 0, 'weight_sum': 39}
# {'id': 128116, 'path': [477, 191], 'vpra_sum': 0, 'weight_sum': 86}
# {'id': 128117, 'path': [477, 192], 'vpra_sum': 0, 'weight_sum': 86}
# {'id': 128118, 'path': [477, 207], 'vpra_sum': 1, 'weight_sum': 79}
# {'id': 128119, 'path': [477, 212], 'vpra_sum': 1, 'weight_sum': 89}
# {'id': 128120, 'path': [477, 219], 'vpra_sum': 0, 'weight_sum': 71}
# {'id': 128121, 'path': [477, 223], 'vpra_sum': 0, 'weight_sum': 20}
# {'id': 128122, 'path': [477, 225], 'vpra_sum': 0, 'weight_sum': 56}
# {'id': 128123, 'path': [477, 226], 'vpra_sum': 0, 'weight_sum': 87}
# {'id': 128124, 'path': [477, 229], 'vpra_sum': 0, 'weight_sum': 9}
# {'id': 128125, 'path': [477, 239], 'vpra_sum': 0, 'weight_sum': 44}
# {'id': 128126, 'path': [477, 241], 'vpra_sum': 0, 'weight_sum': 28}
# {'id': 128127, 'path': [477, 242], 'vpra_sum': 0, 'weight_sum': 2}
# {'id': 128128, 'path': [477, 243], 'vpra_sum': 0, 'weight_sum': 61}
# {'id': 128129, 'path': [477, 244], 'vpra_sum': 0, 'weight_sum': 16}
# {'id': 128130, 'path': [477, 247], 'vpra_sum': 0, 'weight_sum': 27}
# {'id': 128131, 'path': [477, 264], 'vpra_sum': 0, 'weight_sum': 27}
# {'id': 128132, 'path': [477, 268], 'vpra_sum': 0, 'weight_sum': 76}
# {'id': 128133, 'path': [477, 269], 'vpra_sum': 0, 'weight_sum': 1}
# {'id': 128134, 'path': [477, 272], 'vpra_sum': 2, 'weight_sum': 1}
# {'id': 128135, 'path': [477, 273], 'vpra_sum': 0, 'weight_sum': 78}
# {'id': 128136, 'path': [477, 276], 'vpra_sum': 0, 'weight_sum': 31}
# {'id': 128137, 'path': [477, 277], 'vpra_sum': 0, 'weight_sum': 26}
# {'id': 128138, 'path': [477, 278], 'vpra_sum': 0, 'weight_sum': 71}
# {'id': 128139, 'path': [477, 281], 'vpra_sum': 2, 'weight_sum': 88}
# {'id': 128140, 'path': [477, 282], 'vpra_sum': 0, 'weight_sum': 50}
# {'id': 128141, 'path': [477, 284], 'vpra_sum': 0, 'weight_sum': 21}
# {'id': 128142, 'path': [477, 294], 'vpra_sum': 0, 'weight_sum': 67}
# {'id': 128143, 'path': [477, 300], 'vpra_sum': 0, 'weight_sum': 3}
# {'id': 128144, 'path': [477, 303], 'vpra_sum': 0, 'weight_sum': 18}
# {'id': 128145, 'path': [477, 308], 'vpra_sum': 0, 'weight_sum': 66}
# {'id': 128146, 'path': [477, 317], 'vpra_sum': 0, 'weight_sum': 11}
# {'id': 128147, 'path': [477, 320], 'vpra_sum': 0, 'weight_sum': 74}
# {'id': 128148, 'path': [477, 321], 'vpra_sum': 1, 'weight_sum': 43}
# {'id': 128149, 'path': [477, 322], 'vpra_sum': 0, 'weight_sum': 46}
# {'id': 128150, 'path': [477, 323], 'vpra_sum': 0, 'weight_sum': 17}
# {'id': 128151, 'path': [477, 328], 'vpra_sum': 0, 'weight_sum': 15}
# {'id': 128152, 'path': [477, 331], 'vpra_sum': 0, 'weight_sum': 13}
# {'id': 128153, 'path': [477, 334], 'vpra_sum': 1, 'weight_sum': 12}
# {'id': 128154, 'path': [477, 335], 'vpra_sum': 0, 'weight_sum': 5}
# {'id': 128155, 'path': [477, 337], 'vpra_sum': 2, 'weight_sum': 9}
# {'id': 128156, 'path': [477, 339], 'vpra_sum': 0, 'weight_sum': 55}
# {'id': 128157, 'path': [477, 341], 'vpra_sum': 0, 'weight_sum': 25}
# {'id': 128158, 'path': [477, 343], 'vpra_sum': 2, 'weight_sum': 42}
# {'id': 128159, 'path': [477, 349], 'vpra_sum': 0, 'weight_sum': 87}
# {'id': 128160, 'path': [477, 351], 'vpra_sum': 0, 'weight_sum': 3}
# {'id': 128161, 'path': [477, 354], 'vpra_sum': 0, 'weight_sum': 24}
# {'id': 128162, 'path': [477, 356], 'vpra_sum': 0, 'weight_sum': 14}
# {'id': 128163, 'path': [477, 363], 'vpra_sum': 0, 'weight_sum': 58}
# {'id': 128164, 'path': [477, 365], 'vpra_sum': 0, 'weight_sum': 21}
# {'id': 128165, 'path': [477, 366], 'vpra_sum': 0, 'weight_sum': 32}
# {'id': 128166, 'path': [477, 370], 'vpra_sum': 0, 'weight_sum': 6}
# {'id': 128167, 'path': [477, 373], 'vpra_sum': 0, 'weight_sum': 86}
# {'id': 128168, 'path': [477, 374], 'vpra_sum': 0, 'weight_sum': 19}
# {'id': 128169, 'path': [477, 377], 'vpra_sum': 0, 'weight_sum': 39}
# {'id': 128170, 'path': [477, 379], 'vpra_sum': 0, 'weight_sum': 29}
# {'id': 128171, 'path': [477, 397], 'vpra_sum': 0, 'weight_sum': 66}
# {'id': 128172, 'path': [477, 402], 'vpra_sum': 0, 'weight_sum': 77}
# {'id': 128173, 'path': [477, 404], 'vpra_sum': 0, 'weight_sum': 56}
# {'id': 128174, 'path': [477, 405], 'vpra_sum': 1, 'weight_sum': 87}
# {'id': 128175, 'path': [477, 410], 'vpra_sum': 0, 'weight_sum': 3}
# {'id': 128176, 'path': [477, 412], 'vpra_sum': 0, 'weight_sum': 10}
# {'id': 128177, 'path': [477, 413], 'vpra_sum': 0, 'weight_sum': 78}
# {'id': 128178, 'path': [477, 419], 'vpra_sum': 2, 'weight_sum': 86}
# {'id': 128179, 'path': [477, 420], 'vpra_sum': 0, 'weight_sum': 77}
# {'id': 128180, 'path': [477, 421], 'vpra_sum': 0, 'weight_sum': 26}
# {'id': 128181, 'path': [477, 422], 'vpra_sum': 0, 'weight_sum': 43}
# {'id': 128182, 'path': [477, 425], 'vpra_sum': 1, 'weight_sum': 15}
# {'id': 128183, 'path': [477, 427], 'vpra_sum': 0, 'weight_sum': 28}
# {'id': 128184, 'path': [477, 429], 'vpra_sum': 0, 'weight_sum': 13}
# {'id': 128185, 'path': [477, 433], 'vpra_sum': 2, 'weight_sum': 65}
# {'id': 128186, 'path': [477, 435], 'vpra_sum': 1, 'weight_sum': 39}
# {'id': 128187, 'path': [477, 439], 'vpra_sum': 0, 'weight_sum': 3}
# {'id': 128188, 'path': [477, 450], 'vpra_sum': 0, 'weight_sum': 24}
# {'id': 128189, 'path': [477, 454], 'vpra_sum': 2, 'weight_sum': 64}
# {'id': 128190, 'path': [477, 457], 'vpra_sum': 0, 'weight_sum': 65}
# {'id': 128191, 'path': [477, 458], 'vpra_sum': 0, 'weight_sum': 14}
# {'id': 128192, 'path': [477, 461], 'vpra_sum': 0, 'weight_sum': 13}
# {'id': 128193, 'path': [477, 471], 'vpra_sum': 0, 'weight_sum': 84}
# {'id': 128194, 'path': [477, 472], 'vpra_sum': 0, 'weight_sum': 9}
# {'id': 128195, 'path': [478, 4], 'vpra_sum': 0, 'weight_sum': 47}
# {'id': 128196, 'path': [478, 8], 'vpra_sum': 0, 'weight_sum': 70}
# {'id': 128197, 'path': [478, 12], 'vpra_sum': 1, 'weight_sum': 56}
# {'id': 128198, 'path': [478, 14], 'vpra_sum': 0, 'weight_sum': 81}
# {'id': 128199, 'path': [478, 16], 'vpra_sum': 1, 'weight_sum': 50}
# {'id': 128200, 'path': [478, 19], 'vpra_sum': 0, 'weight_sum': 84}
# {'id': 128201, 'path': [478, 21], 'vpra_sum': 0, 'weight_sum': 55}
# {'id': 128202, 'path': [478, 31], 'vpra_sum': 1, 'weight_sum': 37}
# {'id': 128203, 'path': [478, 35], 'vpra_sum': 0, 'weight_sum': 60}
# {'id': 128204, 'path': [478, 36], 'vpra_sum': 0, 'weight_sum': 31}
# {'id': 128205, 'path': [478, 49], 'vpra_sum': 2, 'weight_sum': 34}
# {'id': 128206, 'path': [478, 52], 'vpra_sum': 1, 'weight_sum': 27}
# {'id': 128207, 'path': [478, 57], 'vpra_sum': 0, 'weight_sum': 72}
# {'id': 128208, 'path': [478, 62], 'vpra_sum': 0, 'weight_sum': 88}
# {'id': 128209, 'path': [478, 63], 'vpra_sum': 0, 'weight_sum': 3}
# {'id': 128210, 'path': [478, 67], 'vpra_sum': 1, 'weight_sum': 87}
# {'id': 128211, 'path': [478, 78], 'vpra_sum': 0, 'weight_sum': 25}
# {'id': 128212, 'path': [478, 80], 'vpra_sum': 1, 'weight_sum': 79}
# {'id': 128213, 'path': [478, 88], 'vpra_sum': 0, 'weight_sum': 42}
# {'id': 128214, 'path': [478, 93], 'vpra_sum': 0, 'weight_sum': 43}
# {'id': 128215, 'path': [478, 94], 'vpra_sum': 0, 'weight_sum': 81}
# {'id': 128216, 'path': [478, 99], 'vpra_sum': 0, 'weight_sum': 56}
# {'id': 128217, 'path': [478, 111], 'vpra_sum': 1, 'weight_sum': 37}
# {'id': 128218, 'path': [478, 115], 'vpra_sum': 0, 'weight_sum': 12}
# {'id': 128219, 'path': [478, 118], 'vpra_sum': 0, 'weight_sum': 58}
# {'id': 128220, 'path': [478, 119], 'vpra_sum': 0, 'weight_sum': 30}
# {'id': 128221, 'path': [478, 136], 'vpra_sum': 0, 'weight_sum': 58}
# {'id': 128222, 'path': [478, 144], 'vpra_sum': 0, 'weight_sum': 75}
# {'id': 128223, 'path': [478, 148], 'vpra_sum': 0, 'weight_sum': 71}
# {'id': 128224, 'path': [478, 150], 'vpra_sum': 0, 'weight_sum': 84}
# {'id': 128225, 'path': [478, 151], 'vpra_sum': 1, 'weight_sum': 26}
# {'id': 128226, 'path': [478, 163], 'vpra_sum': 0, 'weight_sum': 20}
# {'id': 128227, 'path': [478, 164], 'vpra_sum': 0, 'weight_sum': 65}
# {'id': 128228, 'path': [478, 166], 'vpra_sum': 0, 'weight_sum': 68}
# {'id': 128229, 'path': [478, 168], 'vpra_sum': 0, 'weight_sum': 48}
# {'id': 128230, 'path': [478, 186], 'vpra_sum': 0, 'weight_sum': 39}
# {'id': 128231, 'path': [478, 189], 'vpra_sum': 0, 'weight_sum': 48}
# {'id': 128232, 'path': [478, 190], 'vpra_sum': 0, 'weight_sum': 1}
# {'id': 128233, 'path': [478, 192], 'vpra_sum': 0, 'weight_sum': 69}
# {'id': 128234, 'path': [478, 223], 'vpra_sum': 0, 'weight_sum': 14}
# {'id': 128235, 'path': [478, 225], 'vpra_sum': 0, 'weight_sum': 16}
# {'id': 128236, 'path': [478, 226], 'vpra_sum': 0, 'weight_sum': 72}
# {'id': 128237, 'path': [478, 229], 'vpra_sum': 0, 'weight_sum': 8}
# {'id': 128238, 'path': [478, 239], 'vpra_sum': 0, 'weight_sum': 27}
# {'id': 128239, 'path': [478, 241], 'vpra_sum': 0, 'weight_sum': 31}
# {'id': 128240, 'path': [478, 242], 'vpra_sum': 0, 'weight_sum': 62}
# {'id': 128241, 'path': [478, 243], 'vpra_sum': 0, 'weight_sum': 84}
# {'id': 128242, 'path': [478, 244], 'vpra_sum': 0, 'weight_sum': 5}
# {'id': 128243, 'path': [478, 247], 'vpra_sum': 0, 'weight_sum': 24}
# {'id': 128244, 'path': [478, 255], 'vpra_sum': 1, 'weight_sum': 54}
# {'id': 128245, 'path': [478, 259], 'vpra_sum': 0, 'weight_sum': 23}
# {'id': 128246, 'path': [478, 262], 'vpra_sum': 1, 'weight_sum': 75}
# {'id': 128247, 'path': [478, 264], 'vpra_sum': 0, 'weight_sum': 65}
# {'id': 128248, 'path': [478, 269], 'vpra_sum': 0, 'weight_sum': 88}
# {'id': 128249, 'path': [478, 273], 'vpra_sum': 0, 'weight_sum': 83}
# {'id': 128250, 'path': [478, 276], 'vpra_sum': 0, 'weight_sum': 54}
# {'id': 128251, 'path': [478, 277], 'vpra_sum': 0, 'weight_sum': 3}
# {'id': 128252, 'path': [478, 278], 'vpra_sum': 0, 'weight_sum': 13}
# {'id': 128253, 'path': [478, 282], 'vpra_sum': 0, 'weight_sum': 45}
# {'id': 128254, 'path': [478, 284], 'vpra_sum': 0, 'weight_sum': 70}
# {'id': 128255, 'path': [478, 296], 'vpra_sum': 2, 'weight_sum': 26}
# {'id': 128256, 'path': [478, 297], 'vpra_sum': 1, 'weight_sum': 36}
# {'id': 128257, 'path': [478, 300], 'vpra_sum': 0, 'weight_sum': 67}
# {'id': 128258, 'path': [478, 303], 'vpra_sum': 0, 'weight_sum': 58}
# {'id': 128259, 'path': [478, 308], 'vpra_sum': 0, 'weight_sum': 67}
# {'id': 128260, 'path': [478, 311], 'vpra_sum': 1, 'weight_sum': 45}
# {'id': 128261, 'path': [478, 317], 'vpra_sum': 0, 'weight_sum': 42}
# {'id': 128262, 'path': [478, 320], 'vpra_sum': 0, 'weight_sum': 28}
# {'id': 128263, 'path': [478, 321], 'vpra_sum': 1, 'weight_sum': 4}
# {'id': 128264, 'path': [478, 322], 'vpra_sum': 0, 'weight_sum': 6}
# {'id': 128265, 'path': [478, 323], 'vpra_sum': 0, 'weight_sum': 29}
# {'id': 128266, 'path': [478, 328], 'vpra_sum': 0, 'weight_sum': 58}
# {'id': 128267, 'path': [478, 331], 'vpra_sum': 0, 'weight_sum': 63}
# {'id': 128268, 'path': [478, 336], 'vpra_sum': 2, 'weight_sum': 63}
# {'id': 128269, 'path': [478, 339], 'vpra_sum': 0, 'weight_sum': 21}
# {'id': 128270, 'path': [478, 341], 'vpra_sum': 0, 'weight_sum': 37}
# {'id': 128271, 'path': [478, 349], 'vpra_sum': 0, 'weight_sum': 74}
# {'id': 128272, 'path': [478, 351], 'vpra_sum': 0, 'weight_sum': 33}
# {'id': 128273, 'path': [478, 354], 'vpra_sum': 0, 'weight_sum': 19}
# {'id': 128274, 'path': [478, 356], 'vpra_sum': 0, 'weight_sum': 20}
# {'id': 128275, 'path': [478, 363], 'vpra_sum': 0, 'weight_sum': 9}
# {'id': 128276, 'path': [478, 365], 'vpra_sum': 0, 'weight_sum': 45}
# {'id': 128277, 'path': [478, 366], 'vpra_sum': 0, 'weight_sum': 85}
# {'id': 128278, 'path': [478, 370], 'vpra_sum': 0, 'weight_sum': 63}
# {'id': 128279, 'path': [478, 373], 'vpra_sum': 0, 'weight_sum': 81}
# {'id': 128280, 'path': [478, 374], 'vpra_sum': 0, 'weight_sum': 85}
# {'id': 128281, 'path': [478, 377], 'vpra_sum': 0, 'weight_sum': 2}
# {'id': 128282, 'path': [478, 378], 'vpra_sum': 1, 'weight_sum': 89}
# {'id': 128283, 'path': [478, 379], 'vpra_sum': 0, 'weight_sum': 67}
# {'id': 128284, 'path': [478, 397], 'vpra_sum': 0, 'weight_sum': 48}
# {'id': 128285, 'path': [478, 400], 'vpra_sum': 1, 'weight_sum': 20}
# {'id': 128286, 'path': [478, 402], 'vpra_sum': 0, 'weight_sum': 4}
# {'id': 128287, 'path': [478, 404], 'vpra_sum': 0, 'weight_sum': 70}
# {'id': 128288, 'path': [478, 410], 'vpra_sum': 0, 'weight_sum': 69}
# {'id': 128289, 'path': [478, 411], 'vpra_sum': 0, 'weight_sum': 24}
# {'id': 128290, 'path': [478, 412], 'vpra_sum': 0, 'weight_sum': 29}
# {'id': 128291, 'path': [478, 413], 'vpra_sum': 0, 'weight_sum': 10}
# {'id': 128292, 'path': [478, 419], 'vpra_sum': 2, 'weight_sum': 0}
# {'id': 128293, 'path': [478, 420], 'vpra_sum': 0, 'weight_sum': 12}
# {'id': 128294, 'path': [478, 421], 'vpra_sum': 0, 'weight_sum': 29}
# {'id': 128295, 'path': [478, 422], 'vpra_sum': 0, 'weight_sum': 17}
# {'id': 128296, 'path': [478, 423], 'vpra_sum': 0, 'weight_sum': 39}
# {'id': 128297, 'path': [478, 427], 'vpra_sum': 0, 'weight_sum': 71}
# {'id': 128298, 'path': [478, 429], 'vpra_sum': 0, 'weight_sum': 4}
# {'id': 128299, 'path': [478, 439], 'vpra_sum': 0, 'weight_sum': 70}
# {'id': 128300, 'path': [478, 442], 'vpra_sum': 0, 'weight_sum': 42}
# {'id': 128301, 'path': [478, 446], 'vpra_sum': 0, 'weight_sum': 36}
# {'id': 128302, 'path': [478, 449], 'vpra_sum': 0, 'weight_sum': 27}
# {'id': 128303, 'path': [478, 457], 'vpra_sum': 0, 'weight_sum': 32}
# {'id': 128304, 'path': [478, 458], 'vpra_sum': 0, 'weight_sum': 62}
# {'id': 128305, 'path': [478, 460], 'vpra_sum': 1, 'weight_sum': 5}
# {'id': 128306, 'path': [478, 461], 'vpra_sum': 0, 'weight_sum': 35}
# {'id': 128307, 'path': [478, 466], 'vpra_sum': 1, 'weight_sum': 83}
# {'id': 128308, 'path': [478, 471], 'vpra_sum': 0, 'weight_sum': 46}
# {'id': 128309, 'path': [478, 472], 'vpra_sum': 0, 'weight_sum': 60}
# {'id': 128310, 'path': [479, 4], 'vpra_sum': 0, 'weight_sum': 2}
# {'id': 128311, 'path': [479, 8], 'vpra_sum': 0, 'weight_sum': 72}
# {'id': 128312, 'path': [479, 12], 'vpra_sum': 1, 'weight_sum': 49}
# {'id': 128313, 'path': [479, 14], 'vpra_sum': 0, 'weight_sum': 34}
# {'id': 128314, 'path': [479, 16], 'vpra_sum': 1, 'weight_sum': 12}
# {'id': 128315, 'path': [479, 19], 'vpra_sum': 0, 'weight_sum': 78}
# {'id': 128316, 'path': [479, 21], 'vpra_sum': 0, 'weight_sum': 73}
# {'id': 128317, 'path': [479, 35], 'vpra_sum': 0, 'weight_sum': 83}
# {'id': 128318, 'path': [479, 36], 'vpra_sum': 0, 'weight_sum': 24}
# {'id': 128319, 'path': [479, 48], 'vpra_sum': 2, 'weight_sum': 6}
# {'id': 128320, 'path': [479, 50], 'vpra_sum': 0, 'weight_sum': 36}
# {'id': 128321, 'path': [479, 57], 'vpra_sum': 0, 'weight_sum': 17}
# {'id': 128322, 'path': [479, 62], 'vpra_sum': 0, 'weight_sum': 43}
# {'id': 128323, 'path': [479, 63], 'vpra_sum': 0, 'weight_sum': 20}
# {'id': 128324, 'path': [479, 66], 'vpra_sum': 0, 'weight_sum': 41}
# {'id': 128325, 'path': [479, 67], 'vpra_sum': 1, 'weight_sum': 63}
# {'id': 128326, 'path': [479, 78], 'vpra_sum': 0, 'weight_sum': 24}
# {'id': 128327, 'path': [479, 79], 'vpra_sum': 1, 'weight_sum': 57}
# {'id': 128328, 'path': [479, 80], 'vpra_sum': 1, 'weight_sum': 20}
# {'id': 128329, 'path': [479, 88], 'vpra_sum': 0, 'weight_sum': 34}
# {'id': 128330, 'path': [479, 93], 'vpra_sum': 0, 'weight_sum': 56}
# {'id': 128331, 'path': [479, 94], 'vpra_sum': 0, 'weight_sum': 12}
# {'id': 128332, 'path': [479, 99], 'vpra_sum': 0, 'weight_sum': 19}
# {'id': 128333, 'path': [479, 115], 'vpra_sum': 0, 'weight_sum': 6}
# {'id': 128334, 'path': [479, 119], 'vpra_sum': 0, 'weight_sum': 16}
# {'id': 128335, 'path': [479, 136], 'vpra_sum': 0, 'weight_sum': 11}
# {'id': 128336, 'path': [479, 144], 'vpra_sum': 0, 'weight_sum': 38}
# {'id': 128337, 'path': [479, 148], 'vpra_sum': 0, 'weight_sum': 24}
# {'id': 128338, 'path': [479, 158], 'vpra_sum': 2, 'weight_sum': 68}
# {'id': 128339, 'path': [479, 163], 'vpra_sum': 0, 'weight_sum': 63}
# {'id': 128340, 'path': [479, 164], 'vpra_sum': 0, 'weight_sum': 74}
# {'id': 128341, 'path': [479, 166], 'vpra_sum': 0, 'weight_sum': 15}
# {'id': 128342, 'path': [479, 168], 'vpra_sum': 0, 'weight_sum': 80}
# {'id': 128343, 'path': [479, 186], 'vpra_sum': 0, 'weight_sum': 76}
# {'id': 128344, 'path': [479, 189], 'vpra_sum': 0, 'weight_sum': 60}
# {'id': 128345, 'path': [479, 190], 'vpra_sum': 0, 'weight_sum': 40}
# {'id': 128346, 'path': [479, 191], 'vpra_sum': 0, 'weight_sum': 73}
# {'id': 128347, 'path': [479, 192], 'vpra_sum': 0, 'weight_sum': 60}
# {'id': 128348, 'path': [479, 219], 'vpra_sum': 0, 'weight_sum': 71}
# {'id': 128349, 'path': [479, 223], 'vpra_sum': 0, 'weight_sum': 70}
# {'id': 128350, 'path': [479, 225], 'vpra_sum': 0, 'weight_sum': 77}
# {'id': 128351, 'path': [479, 226], 'vpra_sum': 0, 'weight_sum': 69}
# {'id': 128352, 'path': [479, 229], 'vpra_sum': 0, 'weight_sum': 45}
# {'id': 128353, 'path': [479, 239], 'vpra_sum': 0, 'weight_sum': 22}
# {'id': 128354, 'path': [479, 241], 'vpra_sum': 0, 'weight_sum': 52}
# {'id': 128355, 'path': [479, 242], 'vpra_sum': 0, 'weight_sum': 86}
# {'id': 128356, 'path': [479, 243], 'vpra_sum': 0, 'weight_sum': 86}
# {'id': 128357, 'path': [479, 244], 'vpra_sum': 0, 'weight_sum': 26}
# {'id': 128358, 'path': [479, 245], 'vpra_sum': 1, 'weight_sum': 4}
# {'id': 128359, 'path': [479, 246], 'vpra_sum': 2, 'weight_sum': 67}
# {'id': 128360, 'path': [479, 247], 'vpra_sum': 0, 'weight_sum': 41}
# {'id': 128361, 'path': [479, 249], 'vpra_sum': 2, 'weight_sum': 57}
# {'id': 128362, 'path': [479, 255], 'vpra_sum': 1, 'weight_sum': 61}
# {'id': 128363, 'path': [479, 259], 'vpra_sum': 0, 'weight_sum': 1}
# {'id': 128364, 'path': [479, 264], 'vpra_sum': 0, 'weight_sum': 34}
# {'id': 128365, 'path': [479, 268], 'vpra_sum': 0, 'weight_sum': 79}
# {'id': 128366, 'path': [479, 269], 'vpra_sum': 0, 'weight_sum': 15}
# {'id': 128367, 'path': [479, 273], 'vpra_sum': 0, 'weight_sum': 60}
# {'id': 128368, 'path': [479, 276], 'vpra_sum': 0, 'weight_sum': 50}
# {'id': 128369, 'path': [479, 277], 'vpra_sum': 0, 'weight_sum': 70}
# {'id': 128370, 'path': [479, 278], 'vpra_sum': 0, 'weight_sum': 81}
# {'id': 128371, 'path': [479, 282], 'vpra_sum': 0, 'weight_sum': 70}
# {'id': 128372, 'path': [479, 294], 'vpra_sum': 0, 'weight_sum': 82}
# {'id': 128373, 'path': [479, 298], 'vpra_sum': 1, 'weight_sum': 75}
# {'id': 128374, 'path': [479, 300], 'vpra_sum': 0, 'weight_sum': 68}
# {'id': 128375, 'path': [479, 303], 'vpra_sum': 0, 'weight_sum': 23}
# {'id': 128376, 'path': [479, 308], 'vpra_sum': 0, 'weight_sum': 6}
# {'id': 128377, 'path': [479, 314], 'vpra_sum': 2, 'weight_sum': 46}
# {'id': 128378, 'path': [479, 317], 'vpra_sum': 0, 'weight_sum': 15}
# {'id': 128379, 'path': [479, 321], 'vpra_sum': 1, 'weight_sum': 88}
# {'id': 128380, 'path': [479, 322], 'vpra_sum': 0, 'weight_sum': 80}
# {'id': 128381, 'path': [479, 323], 'vpra_sum': 0, 'weight_sum': 23}
# {'id': 128382, 'path': [479, 328], 'vpra_sum': 0, 'weight_sum': 73}
# {'id': 128383, 'path': [479, 331], 'vpra_sum': 0, 'weight_sum': 47}
# {'id': 128384, 'path': [479, 334], 'vpra_sum': 1, 'weight_sum': 54}
# {'id': 128385, 'path': [479, 339], 'vpra_sum': 0, 'weight_sum': 9}
# {'id': 128386, 'path': [479, 341], 'vpra_sum': 0, 'weight_sum': 77}
# {'id': 128387, 'path': [479, 348], 'vpra_sum': 1, 'weight_sum': 45}
# {'id': 128388, 'path': [479, 349], 'vpra_sum': 0, 'weight_sum': 32}
# {'id': 128389, 'path': [479, 351], 'vpra_sum': 0, 'weight_sum': 25}
# {'id': 128390, 'path': [479, 354], 'vpra_sum': 0, 'weight_sum': 11}
# {'id': 128391, 'path': [479, 356], 'vpra_sum': 0, 'weight_sum': 48}
# {'id': 128392, 'path': [479, 360], 'vpra_sum': 2, 'weight_sum': 31}
# {'id': 128393, 'path': [479, 363], 'vpra_sum': 0, 'weight_sum': 14}
# {'id': 128394, 'path': [479, 365], 'vpra_sum': 0, 'weight_sum': 30}
# {'id': 128395, 'path': [479, 366], 'vpra_sum': 0, 'weight_sum': 58}
# {'id': 128396, 'path': [479, 370], 'vpra_sum': 0, 'weight_sum': 79}
# {'id': 128397, 'path': [479, 372], 'vpra_sum': 1, 'weight_sum': 57}
# {'id': 128398, 'path': [479, 373], 'vpra_sum': 0, 'weight_sum': 34}
# {'id': 128399, 'path': [479, 374], 'vpra_sum': 0, 'weight_sum': 3}
# {'id': 128400, 'path': [479, 377], 'vpra_sum': 0, 'weight_sum': 27}
# {'id': 128401, 'path': [479, 397], 'vpra_sum': 0, 'weight_sum': 40}
# {'id': 128402, 'path': [479, 400], 'vpra_sum': 1, 'weight_sum': 34}
# {'id': 128403, 'path': [479, 401], 'vpra_sum': 1, 'weight_sum': 87}
# {'id': 128404, 'path': [479, 402], 'vpra_sum': 0, 'weight_sum': 6}
# {'id': 128405, 'path': [479, 404], 'vpra_sum': 0, 'weight_sum': 18}
# {'id': 128406, 'path': [479, 409], 'vpra_sum': 2, 'weight_sum': 59}
# {'id': 128407, 'path': [479, 410], 'vpra_sum': 0, 'weight_sum': 34}
# {'id': 128408, 'path': [479, 412], 'vpra_sum': 0, 'weight_sum': 28}
# {'id': 128409, 'path': [479, 413], 'vpra_sum': 0, 'weight_sum': 17}
# {'id': 128410, 'path': [479, 420], 'vpra_sum': 0, 'weight_sum': 41}
# {'id': 128411, 'path': [479, 421], 'vpra_sum': 0, 'weight_sum': 24}
# {'id': 128412, 'path': [479, 422], 'vpra_sum': 0, 'weight_sum': 48}
# {'id': 128413, 'path': [479, 427], 'vpra_sum': 0, 'weight_sum': 15}
# {'id': 128414, 'path': [479, 429], 'vpra_sum': 0, 'weight_sum': 17}
# {'id': 128415, 'path': [479, 438], 'vpra_sum': 1, 'weight_sum': 53}
# {'id': 128416, 'path': [479, 439], 'vpra_sum': 0, 'weight_sum': 63}
# {'id': 128417, 'path': [479, 444], 'vpra_sum': 2, 'weight_sum': 14}
# {'id': 128418, 'path': [479, 445], 'vpra_sum': 0, 'weight_sum': 36}
# {'id': 128419, 'path': [479, 449], 'vpra_sum': 0, 'weight_sum': 65}
# {'id': 128420, 'path': [479, 457], 'vpra_sum': 0, 'weight_sum': 39}
# {'id': 128421, 'path': [479, 458], 'vpra_sum': 0, 'weight_sum': 24}
# {'id': 128422, 'path': [479, 461], 'vpra_sum': 0, 'weight_sum': 34}
# {'id': 128423, 'path': [479, 468], 'vpra_sum': 0, 'weight_sum': 35}
# {'id': 128424, 'path': [479, 471], 'vpra_sum': 0, 'weight_sum': 44}
# {'id': 128425, 'path': [479, 473], 'vpra_sum': 1, 'weight_sum': 35}
# {'id': 128426, 'path': [480, 25], 'vpra_sum': 2, 'weight_sum': 19}
# {'id': 128427, 'path': [480, 36], 'vpra_sum': 0, 'weight_sum': 9}
# {'id': 128428, 'path': [480, 87], 'vpra_sum': 1, 'weight_sum': 65}
# {'id': 128429, 'path': [480, 129], 'vpra_sum': 1, 'weight_sum': 50}
# {'id': 128430, 'path': [480, 148], 'vpra_sum': 0, 'weight_sum': 26}
# {'id': 128431, 'path': [480, 166], 'vpra_sum': 0, 'weight_sum': 54}
# {'id': 128432, 'path': [480, 242], 'vpra_sum': 0, 'weight_sum': 63}
# {'id': 128433, 'path': [480, 298], 'vpra_sum': 1, 'weight_sum': 16}
# {'id': 128434, 'path': [480, 320], 'vpra_sum': 0, 'weight_sum': 25}
# {'id': 128435, 'path': [480, 325], 'vpra_sum': 0, 'weight_sum': 12}
# {'id': 128436, 'path': [480, 335], 'vpra_sum': 0, 'weight_sum': 84}
# {'id': 128437, 'path': [480, 394], 'vpra_sum': 1, 'weight_sum': 25}
# {'id': 128438, 'path': [480, 403], 'vpra_sum': 2, 'weight_sum': 12}
# {'id': 128439, 'path': [481, 4], 'vpra_sum': 0, 'weight_sum': 17}
# {'id': 128440, 'path': [481, 14], 'vpra_sum': 0, 'weight_sum': 1}
# {'id': 128441, 'path': [481, 16], 'vpra_sum': 1, 'weight_sum': 15}
# {'id': 128442, 'path': [481, 19], 'vpra_sum': 0, 'weight_sum': 82}
# {'id': 128443, 'path': [481, 21], 'vpra_sum': 0, 'weight_sum': 62}
# {'id': 128444, 'path': [481, 22], 'vpra_sum': 1, 'weight_sum': 79}
# {'id': 128445, 'path': [481, 35], 'vpra_sum': 0, 'weight_sum': 18}
# {'id': 128446, 'path': [481, 36], 'vpra_sum': 0, 'weight_sum': 50}
# {'id': 128447, 'path': [481, 50], 'vpra_sum': 0, 'weight_sum': 42}
# {'id': 128448, 'path': [481, 57], 'vpra_sum': 0, 'weight_sum': 78}
# {'id': 128449, 'path': [481, 62], 'vpra_sum': 0, 'weight_sum': 39}
# {'id': 128450, 'path': [481, 63], 'vpra_sum': 0, 'weight_sum': 24}
# {'id': 128451, 'path': [481, 78], 'vpra_sum': 0, 'weight_sum': 3}
# {'id': 128452, 'path': [481, 83], 'vpra_sum': 2, 'weight_sum': 28}
# {'id': 128453, 'path': [481, 88], 'vpra_sum': 0, 'weight_sum': 9}
# {'id': 128454, 'path': [481, 93], 'vpra_sum': 0, 'weight_sum': 7}
# {'id': 128455, 'path': [481, 94], 'vpra_sum': 0, 'weight_sum': 56}
# {'id': 128456, 'path': [481, 99], 'vpra_sum': 0, 'weight_sum': 30}
# {'id': 128457, 'path': [481, 115], 'vpra_sum': 0, 'weight_sum': 27}
# {'id': 128458, 'path': [481, 118], 'vpra_sum': 0, 'weight_sum': 2}
# {'id': 128459, 'path': [481, 125], 'vpra_sum': 1, 'weight_sum': 13}
# {'id': 128460, 'path': [481, 136], 'vpra_sum': 0, 'weight_sum': 72}
# {'id': 128461, 'path': [481, 144], 'vpra_sum': 0, 'weight_sum': 13}
# {'id': 128462, 'path': [481, 148], 'vpra_sum': 0, 'weight_sum': 56}
# {'id': 128463, 'path': [481, 157], 'vpra_sum': 2, 'weight_sum': 45}
# {'id': 128464, 'path': [481, 163], 'vpra_sum': 0, 'weight_sum': 15}
# {'id': 128465, 'path': [481, 164], 'vpra_sum': 0, 'weight_sum': 58}
# {'id': 128466, 'path': [481, 166], 'vpra_sum': 0, 'weight_sum': 79}
# {'id': 128467, 'path': [481, 171], 'vpra_sum': 1, 'weight_sum': 62}
# {'id': 128468, 'path': [481, 186], 'vpra_sum': 0, 'weight_sum': 23}
# {'id': 128469, 'path': [481, 189], 'vpra_sum': 0, 'weight_sum': 10}
# {'id': 128470, 'path': [481, 190], 'vpra_sum': 0, 'weight_sum': 88}
# {'id': 128471, 'path': [481, 191], 'vpra_sum': 0, 'weight_sum': 20}
# {'id': 128472, 'path': [481, 192], 'vpra_sum': 0, 'weight_sum': 67}
# {'id': 128473, 'path': [481, 223], 'vpra_sum': 0, 'weight_sum': 81}
# {'id': 128474, 'path': [481, 225], 'vpra_sum': 0, 'weight_sum': 89}
# {'id': 128475, 'path': [481, 226], 'vpra_sum': 0, 'weight_sum': 53}
# {'id': 128476, 'path': [481, 229], 'vpra_sum': 0, 'weight_sum': 23}
# {'id': 128477, 'path': [481, 239], 'vpra_sum': 0, 'weight_sum': 81}
# {'id': 128478, 'path': [481, 241], 'vpra_sum': 0, 'weight_sum': 33}
# {'id': 128479, 'path': [481, 242], 'vpra_sum': 0, 'weight_sum': 37}
# {'id': 128480, 'path': [481, 243], 'vpra_sum': 0, 'weight_sum': 71}
# {'id': 128481, 'path': [481, 244], 'vpra_sum': 0, 'weight_sum': 58}
# {'id': 128482, 'path': [481, 245], 'vpra_sum': 1, 'weight_sum': 38}
# {'id': 128483, 'path': [481, 247], 'vpra_sum': 0, 'weight_sum': 1}
# {'id': 128484, 'path': [481, 259], 'vpra_sum': 0, 'weight_sum': 3}
# {'id': 128485, 'path': [481, 264], 'vpra_sum': 0, 'weight_sum': 64}
# {'id': 128486, 'path': [481, 268], 'vpra_sum': 0, 'weight_sum': 32}
# {'id': 128487, 'path': [481, 269], 'vpra_sum': 0, 'weight_sum': 88}
# {'id': 128488, 'path': [481, 276], 'vpra_sum': 0, 'weight_sum': 4}
# {'id': 128489, 'path': [481, 277], 'vpra_sum': 0, 'weight_sum': 48}
# {'id': 128490, 'path': [481, 278], 'vpra_sum': 0, 'weight_sum': 70}
# {'id': 128491, 'path': [481, 282], 'vpra_sum': 0, 'weight_sum': 0}
# {'id': 128492, 'path': [481, 283], 'vpra_sum': 1, 'weight_sum': 75}
# {'id': 128493, 'path': [481, 288], 'vpra_sum': 2, 'weight_sum': 36}
# {'id': 128494, 'path': [481, 294], 'vpra_sum': 0, 'weight_sum': 15}
# {'id': 128495, 'path': [481, 298], 'vpra_sum': 1, 'weight_sum': 24}
# {'id': 128496, 'path': [481, 300], 'vpra_sum': 0, 'weight_sum': 70}
# {'id': 128497, 'path': [481, 303], 'vpra_sum': 0, 'weight_sum': 19}
# {'id': 128498, 'path': [481, 308], 'vpra_sum': 0, 'weight_sum': 56}
# {'id': 128499, 'path': [481, 311], 'vpra_sum': 1, 'weight_sum': 18}
# {'id': 128500, 'path': [481, 317], 'vpra_sum': 0, 'weight_sum': 63}
# {'id': 128501, 'path': [481, 320], 'vpra_sum': 0, 'weight_sum': 3}
# {'id': 128502, 'path': [481, 321], 'vpra_sum': 1, 'weight_sum': 28}
# {'id': 128503, 'path': [481, 322], 'vpra_sum': 0, 'weight_sum': 57}
# {'id': 128504, 'path': [481, 323], 'vpra_sum': 0, 'weight_sum': 33}
# {'id': 128505, 'path': [481, 325], 'vpra_sum': 0, 'weight_sum': 39}
# {'id': 128506, 'path': [481, 328], 'vpra_sum': 0, 'weight_sum': 0}
# {'id': 128507, 'path': [481, 329], 'vpra_sum': 1, 'weight_sum': 65}
# {'id': 128508, 'path': [481, 331], 'vpra_sum': 0, 'weight_sum': 16}
# {'id': 128509, 'path': [481, 335], 'vpra_sum': 0, 'weight_sum': 49}
# {'id': 128510, 'path': [481, 339], 'vpra_sum': 0, 'weight_sum': 24}
# {'id': 128511, 'path': [481, 341], 'vpra_sum': 0, 'weight_sum': 5}
# {'id': 128512, 'path': [481, 349], 'vpra_sum': 0, 'weight_sum': 59}
# {'id': 128513, 'path': [481, 351], 'vpra_sum': 0, 'weight_sum': 87}
# {'id': 128514, 'path': [481, 354], 'vpra_sum': 0, 'weight_sum': 85}
# {'id': 128515, 'path': [481, 356], 'vpra_sum': 0, 'weight_sum': 7}
# {'id': 128516, 'path': [481, 363], 'vpra_sum': 0, 'weight_sum': 31}
# {'id': 128517, 'path': [481, 365], 'vpra_sum': 0, 'weight_sum': 27}
# {'id': 128518, 'path': [481, 366], 'vpra_sum': 0, 'weight_sum': 42}
# {'id': 128519, 'path': [481, 370], 'vpra_sum': 0, 'weight_sum': 7}
# {'id': 128520, 'path': [481, 373], 'vpra_sum': 0, 'weight_sum': 40}
# {'id': 128521, 'path': [481, 374], 'vpra_sum': 0, 'weight_sum': 0}
# {'id': 128522, 'path': [481, 376], 'vpra_sum': 1, 'weight_sum': 75}
# {'id': 128523, 'path': [481, 377], 'vpra_sum': 0, 'weight_sum': 75}
# {'id': 128524, 'path': [481, 379], 'vpra_sum': 0, 'weight_sum': 44}
# {'id': 128525, 'path': [481, 393], 'vpra_sum': 1, 'weight_sum': 43}
# {'id': 128526, 'path': [481, 396], 'vpra_sum': 2, 'weight_sum': 38}
# {'id': 128527, 'path': [481, 397], 'vpra_sum': 0, 'weight_sum': 8}
# {'id': 128528, 'path': [481, 401], 'vpra_sum': 1, 'weight_sum': 60}
# {'id': 128529, 'path': [481, 402], 'vpra_sum': 0, 'weight_sum': 31}
# {'id': 128530, 'path': [481, 404], 'vpra_sum': 0, 'weight_sum': 30}
# {'id': 128531, 'path': [481, 410], 'vpra_sum': 0, 'weight_sum': 26}
# {'id': 128532, 'path': [481, 411], 'vpra_sum': 0, 'weight_sum': 77}
# {'id': 128533, 'path': [481, 412], 'vpra_sum': 0, 'weight_sum': 41}
# {'id': 128534, 'path': [481, 413], 'vpra_sum': 0, 'weight_sum': 4}
# {'id': 128535, 'path': [481, 420], 'vpra_sum': 0, 'weight_sum': 52}
# {'id': 128536, 'path': [481, 421], 'vpra_sum': 0, 'weight_sum': 25}
# {'id': 128537, 'path': [481, 422], 'vpra_sum': 0, 'weight_sum': 13}
# {'id': 128538, 'path': [481, 424], 'vpra_sum': 2, 'weight_sum': 64}
# {'id': 128539, 'path': [481, 425], 'vpra_sum': 1, 'weight_sum': 16}
# {'id': 128540, 'path': [481, 427], 'vpra_sum': 0, 'weight_sum': 52}
# {'id': 128541, 'path': [481, 429], 'vpra_sum': 0, 'weight_sum': 60}
# {'id': 128542, 'path': [481, 431], 'vpra_sum': 2, 'weight_sum': 50}
# {'id': 128543, 'path': [481, 439], 'vpra_sum': 0, 'weight_sum': 75}
# {'id': 128544, 'path': [481, 442], 'vpra_sum': 0, 'weight_sum': 40}
# {'id': 128545, 'path': [481, 445], 'vpra_sum': 0, 'weight_sum': 65}
# ...
# {'id': 165805, 'path': [498, 473, 229], 'vpra_sum': 1, 'weight_sum': 136}
# {'id': 165806, 'path': [498, 473, 239], 'vpra_sum': 1, 'weight_sum': 122}
# {'id': 165807, 'path': [498, 473, 241], 'vpra_sum': 1, 'weight_sum': 78}
# {'id': 165808, 'path': [498, 473, 242], 'vpra_sum': 1, 'weight_sum': 112}
# {'id': 165809, 'path': [498, 473, 243], 'vpra_sum': 1, 'weight_sum': 150}
# {'id': 165810, 'path': [498, 473, 244], 'vpra_sum': 1, 'weight_sum': 103}
# {'id': 165811, 'path': [498, 473, 247], 'vpra_sum': 1, 'weight_sum': 148}
# {'id': 165812, 'path': [498, 473, 255], 'vpra_sum': 2, 'weight_sum': 142}
# {'id': 165813, 'path': [498, 473, 256], 'vpra_sum': 2, 'weight_sum': 154}
# {'id': 165814, 'path': [498, 473, 259], 'vpra_sum': 1, 'weight_sum': 71}
# {'id': 165815, 'path': [498, 473, 262], 'vpra_sum': 2, 'weight_sum': 82}
# {'id': 165816, 'path': [498, 473, 263], 'vpra_sum': 3, 'weight_sum': 140}
# {'id': 165817, 'path': [498, 473, 264], 'vpra_sum': 1, 'weight_sum': 140}
# {'id': 165818, 'path': [498, 473, 269], 'vpra_sum': 1, 'weight_sum': 142}
# {'id': 165819, 'path': [498, 473, 277], 'vpra_sum': 1, 'weight_sum': 120}
# {'id': 165820, 'path': [498, 473, 278], 'vpra_sum': 1, 'weight_sum': 84}
# {'id': 165821, 'path': [498, 473, 282], 'vpra_sum': 1, 'weight_sum': 129}
# {'id': 165822, 'path': [498, 473, 284], 'vpra_sum': 1, 'weight_sum': 148}
# {'id': 165823, 'path': [498, 473, 294], 'vpra_sum': 1, 'weight_sum': 110}
# {'id': 165824, 'path': [498, 473, 297], 'vpra_sum': 2, 'weight_sum': 143}
# {'id': 165825, 'path': [498, 473, 298], 'vpra_sum': 2, 'weight_sum': 159}
# {'id': 165826, 'path': [498, 473, 300], 'vpra_sum': 1, 'weight_sum': 151}
# {'id': 165827, 'path': [498, 473, 301], 'vpra_sum': 3, 'weight_sum': 91}
# {'id': 165828, 'path': [498, 473, 308], 'vpra_sum': 1, 'weight_sum': 122}
# {'id': 165829, 'path': [498, 473, 317], 'vpra_sum': 1, 'weight_sum': 146}
# {'id': 165830, 'path': [498, 473, 322], 'vpra_sum': 1, 'weight_sum': 94}
# {'id': 165831, 'path': [498, 473, 323], 'vpra_sum': 1, 'weight_sum': 150}
# {'id': 165832, 'path': [498, 473, 325], 'vpra_sum': 1, 'weight_sum': 102}
# {'id': 165833, 'path': [498, 473, 328], 'vpra_sum': 1, 'weight_sum': 103}
# {'id': 165834, 'path': [498, 473, 331], 'vpra_sum': 1, 'weight_sum': 110}
# {'id': 165835, 'path': [498, 473, 335], 'vpra_sum': 1, 'weight_sum': 134}
# {'id': 165836, 'path': [498, 473, 336], 'vpra_sum': 3, 'weight_sum': 124}
# {'id': 165837, 'path': [498, 473, 337], 'vpra_sum': 3, 'weight_sum': 79}
# {'id': 165838, 'path': [498, 473, 341], 'vpra_sum': 1, 'weight_sum': 127}
# {'id': 165839, 'path': [498, 473, 349], 'vpra_sum': 1, 'weight_sum': 112}
# {'id': 165840, 'path': [498, 473, 351], 'vpra_sum': 1, 'weight_sum': 153}
# {'id': 165841, 'path': [498, 473, 354], 'vpra_sum': 1, 'weight_sum': 75}
# {'id': 165842, 'path': [498, 473, 356], 'vpra_sum': 1, 'weight_sum': 74}
# {'id': 165843, 'path': [498, 473, 363], 'vpra_sum': 1, 'weight_sum': 77}
# {'id': 165844, 'path': [498, 473, 365], 'vpra_sum': 1, 'weight_sum': 146}
# {'id': 165845, 'path': [498, 473, 366], 'vpra_sum': 1, 'weight_sum': 141}
# {'id': 165846, 'path': [498, 473, 370], 'vpra_sum': 1, 'weight_sum': 82}
# {'id': 165847, 'path': [498, 473, 373], 'vpra_sum': 1, 'weight_sum': 151}
# {'id': 165848, 'path': [498, 473, 374], 'vpra_sum': 1, 'weight_sum': 99}
# {'id': 165849, 'path': [498, 473, 376], 'vpra_sum': 2, 'weight_sum': 94}
# {'id': 165850, 'path': [498, 473, 377], 'vpra_sum': 1, 'weight_sum': 111}
# {'id': 165851, 'path': [498, 473, 379], 'vpra_sum': 1, 'weight_sum': 128}
# {'id': 165852, 'path': [498, 473, 397], 'vpra_sum': 1, 'weight_sum': 117}
# {'id': 165853, 'path': [498, 473, 402], 'vpra_sum': 1, 'weight_sum': 73}
# {'id': 165854, 'path': [498, 473, 404], 'vpra_sum': 1, 'weight_sum': 70}
# {'id': 165855, 'path': [498, 473, 410], 'vpra_sum': 1, 'weight_sum': 80}
# {'id': 165856, 'path': [498, 473, 412], 'vpra_sum': 1, 'weight_sum': 151}
# {'id': 165857, 'path': [498, 473, 413], 'vpra_sum': 1, 'weight_sum': 141}
# {'id': 165858, 'path': [498, 473, 420], 'vpra_sum': 1, 'weight_sum': 108}
# {'id': 165859, 'path': [498, 473, 421], 'vpra_sum': 1, 'weight_sum': 109}
# {'id': 165860, 'path': [498, 473, 422], 'vpra_sum': 1, 'weight_sum': 115}
# {'id': 165861, 'path': [498, 473, 423], 'vpra_sum': 1, 'weight_sum': 77}
# {'id': 165862, 'path': [498, 473, 427], 'vpra_sum': 1, 'weight_sum': 98}
# {'id': 165863, 'path': [498, 473, 439], 'vpra_sum': 1, 'weight_sum': 75}
# {'id': 165864, 'path': [498, 473, 442], 'vpra_sum': 1, 'weight_sum': 75}
# {'id': 165865, 'path': [498, 473, 445], 'vpra_sum': 1, 'weight_sum': 154}
# {'id': 165866, 'path': [498, 473, 449], 'vpra_sum': 1, 'weight_sum': 77}
# {'id': 165867, 'path': [498, 473, 457], 'vpra_sum': 1, 'weight_sum': 146}
# {'id': 165868, 'path': [498, 473, 458], 'vpra_sum': 1, 'weight_sum': 138}
# {'id': 165869, 'path': [498, 473, 460], 'vpra_sum': 2, 'weight_sum': 89}
# {'id': 165870, 'path': [498, 473, 461], 'vpra_sum': 1, 'weight_sum': 147}
# {'id': 165871, 'path': [498, 473, 468], 'vpra_sum': 1, 'weight_sum': 92}
# {'id': 165872, 'path': [498, 473, 471], 'vpra_sum': 1, 'weight_sum': 137}
# {'id': 165873, 'path': [498, 473, 472], 'vpra_sum': 1, 'weight_sum': 128}
# {'id': 165874, 'path': [499, 4, 36], 'vpra_sum': 0, 'weight_sum': 113}
# {'id': 165875, 'path': [499, 4, 148], 'vpra_sum': 0, 'weight_sum': 86}
# {'id': 165876, 'path': [499, 4, 166], 'vpra_sum': 0, 'weight_sum': 141}
# {'id': 165877, 'path': [499, 4, 242], 'vpra_sum': 0, 'weight_sum': 170}
# {'id': 165878, 'path': [499, 4, 276], 'vpra_sum': 0, 'weight_sum': 156}
# {'id': 165879, 'path': [499, 4, 298], 'vpra_sum': 1, 'weight_sum': 111}
# {'id': 165880, 'path': [499, 4, 310], 'vpra_sum': 2, 'weight_sum': 171}
# {'id': 165881, 'path': [499, 4, 331], 'vpra_sum': 0, 'weight_sum': 151}
# {'id': 165882, 'path': [499, 4, 335], 'vpra_sum': 0, 'weight_sum': 120}
# {'id': 165883, 'path': [499, 4, 425], 'vpra_sum': 1, 'weight_sum': 154}
# {'id': 165884, 'path': [499, 4, 466], 'vpra_sum': 1, 'weight_sum': 91}
# {'id': 165885, 'path': [499, 14, 36], 'vpra_sum': 0, 'weight_sum': 122}
# {'id': 165886, 'path': [499, 14, 67], 'vpra_sum': 1, 'weight_sum': 87}
# {'id': 165887, 'path': [499, 14, 148], 'vpra_sum': 0, 'weight_sum': 163}
# {'id': 165888, 'path': [499, 14, 166], 'vpra_sum': 0, 'weight_sum': 86}
# {'id': 165889, 'path': [499, 14, 242], 'vpra_sum': 0, 'weight_sum': 90}
# {'id': 165890, 'path': [499, 14, 289], 'vpra_sum': 2, 'weight_sum': 87}
# {'id': 165891, 'path': [499, 14, 331], 'vpra_sum': 0, 'weight_sum': 133}
# {'id': 165892, 'path': [499, 14, 335], 'vpra_sum': 0, 'weight_sum': 137}
# {'id': 165893, 'path': [499, 21, 36], 'vpra_sum': 0, 'weight_sum': 36}
# {'id': 165894, 'path': [499, 21, 67], 'vpra_sum': 1, 'weight_sum': 47}
# {'id': 165895, 'path': [499, 21, 148], 'vpra_sum': 0, 'weight_sum': 52}
# {'id': 165896, 'path': [499, 21, 166], 'vpra_sum': 0, 'weight_sum': 8}
# {'id': 165897, 'path': [499, 21, 242], 'vpra_sum': 0, 'weight_sum': 24}
# {'id': 165898, 'path': [499, 21, 276], 'vpra_sum': 0, 'weight_sum': 49}
# {'id': 165899, 'path': [499, 21, 283], 'vpra_sum': 1, 'weight_sum': 34}
# {'id': 165900, 'path': [499, 21, 331], 'vpra_sum': 0, 'weight_sum': 11}
# {'id': 165901, 'path': [499, 21, 335], 'vpra_sum': 0, 'weight_sum': 66}
# {'id': 165902, 'path': [499, 21, 387], 'vpra_sum': 2, 'weight_sum': 71}
# {'id': 165903, 'path': [499, 21, 425], 'vpra_sum': 1, 'weight_sum': 12}
# {'id': 165904, 'path': [499, 21, 466], 'vpra_sum': 1, 'weight_sum': 45}
# {'id': 165905, 'path': [499, 397, 120], 'vpra_sum': 1, 'weight_sum': 85}
# {'id': 165906, 'path': [499, 399, 25], 'vpra_sum': 4, 'weight_sum': 39}
# {'id': 165907, 'path': [499, 399, 36], 'vpra_sum': 2, 'weight_sum': 81}
# {'id': 165908, 'path': [499, 399, 116], 'vpra_sum': 3, 'weight_sum': 66}
# {'id': 165909, 'path': [499, 399, 148], 'vpra_sum': 2, 'weight_sum': 56}
# {'id': 165910, 'path': [499, 399, 166], 'vpra_sum': 2, 'weight_sum': 46}
# {'id': 165911, 'path': [499, 399, 231], 'vpra_sum': 4, 'weight_sum': 62}
# {'id': 165912, 'path': [499, 399, 242], 'vpra_sum': 2, 'weight_sum': 78}
# {'id': 165913, 'path': [499, 399, 276], 'vpra_sum': 2, 'weight_sum': 47}
# {'id': 165914, 'path': [499, 399, 325], 'vpra_sum': 2, 'weight_sum': 30}
# {'id': 165915, 'path': [499, 399, 331], 'vpra_sum': 2, 'weight_sum': 67}
# {'id': 165916, 'path': [499, 399, 335], 'vpra_sum': 2, 'weight_sum': 8}
# {'id': 165917, 'path': [499, 411, 25], 'vpra_sum': 2, 'weight_sum': 65}
# {'id': 165918, 'path': [499, 411, 36], 'vpra_sum': 0, 'weight_sum': 33}
# {'id': 165919, 'path': [499, 411, 87], 'vpra_sum': 1, 'weight_sum': 28}
# {'id': 165920, 'path': [499, 411, 129], 'vpra_sum': 1, 'weight_sum': 69}
# {'id': 165921, 'path': [499, 411, 148], 'vpra_sum': 0, 'weight_sum': 6}
# {'id': 165922, 'path': [499, 411, 166], 'vpra_sum': 0, 'weight_sum': 60}
# {'id': 165923, 'path': [499, 411, 231], 'vpra_sum': 2, 'weight_sum': 73}
# {'id': 165924, 'path': [499, 411, 242], 'vpra_sum': 0, 'weight_sum': 59}
# {'id': 165925, 'path': [499, 411, 276], 'vpra_sum': 0, 'weight_sum': 60}
# {'id': 165926, 'path': [499, 411, 298], 'vpra_sum': 1, 'weight_sum': 11}
# {'id': 165927, 'path': [499, 411, 320], 'vpra_sum': 0, 'weight_sum': 68}
# {'id': 165928, 'path': [499, 411, 335], 'vpra_sum': 0, 'weight_sum': 67}
# {'id': 165929, 'path': [499, 411, 394], 'vpra_sum': 1, 'weight_sum': 34}
# {'id': 165930, 'path': [499, 411, 431], 'vpra_sum': 2, 'weight_sum': 80}
# {'id': 165931, 'path': [499, 411, 466], 'vpra_sum': 1, 'weight_sum': 67}
# {'id': 165932, 'path': [499, 461, 36], 'vpra_sum': 0, 'weight_sum': 48}
# {'id': 165933, 'path': [499, 461, 148], 'vpra_sum': 0, 'weight_sum': 70}
# {'id': 165934, 'path': [499, 461, 166], 'vpra_sum': 0, 'weight_sum': 35}
# {'id': 165935, 'path': [499, 461, 176], 'vpra_sum': 2, 'weight_sum': 94}
# {'id': 165936, 'path': [499, 461, 242], 'vpra_sum': 0, 'weight_sum': 33}
# {'id': 165937, 'path': [499, 461, 320], 'vpra_sum': 0, 'weight_sum': 40}
# {'id': 165938, 'path': [499, 461, 325], 'vpra_sum': 0, 'weight_sum': 70}
# {'id': 165939, 'path': [499, 461, 331], 'vpra_sum': 0, 'weight_sum': 85}
# {'id': 165940, 'path': [499, 461, 335], 'vpra_sum': 0, 'weight_sum': 62}
# {'id': 165941, 'path': [499, 461, 345], 'vpra_sum': 2, 'weight_sum': 83}
# {'id': 165942, 'path': [499, 461, 394], 'vpra_sum': 1, 'weight_sum': 49}
# {'id': 165943, 'path': [499, 461, 466], 'vpra_sum': 1, 'weight_sum': 27}
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-29
# Set parameter TimeLimit to value 14400
# Set parameter MIPGap to value 0.001
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 24.0.0 24A335)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 121582 rows, 165944 columns and 735908 nonzeros
# Model fingerprint: 0x16b330ab
# Variable types: 0 continuous, 165944 integer (165944 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 5253.0000000
# Presolve removed 121239 rows and 121107 columns
# Presolve time: 0.04s
# Presolved: 343 rows, 44837 columns, 132333 nonzeros
# Variable types: 0 continuous, 44837 integer (44837 binary)
#
# Starting sifting (using dual simplex for sub-problems)...
#
#     Iter     Pivots    Primal Obj      Dual Obj        Time
#        0          0     infinity     -5.8314800e+05      0s
#        1        307   1.5044463e+10  -4.0578056e+05      0s
#        2        847   1.2686506e+10  -2.4533312e+05      0s
#        3       1273   9.7625836e+09  -1.6903852e+05      0s
#        4       1699   6.2966987e+09  -1.3208969e+05      0s
#        5       2124   4.5097689e+09  -9.8432003e+04      0s
#        6       2557   2.3828634e+09  -7.2944288e+04      0s
#        7       3002   4.2796548e+08  -5.7635504e+04      0s
#        8       3602  -8.0780000e+03  -4.1217093e+04      0s
#        9       4145  -8.4860000e+03  -3.2893498e+04      0s
#       10       4661  -9.3870000e+03  -2.6043999e+04      0s
#       11       5166  -1.0067500e+04  -2.0392067e+04      0s
#       12       5762  -1.0606625e+04  -1.5289884e+04      0s
#       13       6229  -1.0714000e+04  -1.2011246e+04      0s
#
# Sifting complete
#
#
# Root relaxation: objective 1.071950e+04, 6595 iterations, 0.14 seconds (0.09 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 10719.5000    0   23 5253.00000 10719.5000   104%     -    0s
# H    0     0                    10661.000000 10719.5000  0.55%     -    0s
# H    0     0                    10681.000000 10719.5000  0.36%     -    0s
# H    0     0                    10713.000000 10719.5000  0.06%     -    0s
#
# Cutting planes:
#   Zero half: 1
#
# Explored 1 nodes (6598 simplex iterations) in 0.68 seconds (0.66 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 10713 10681 10661 ... 3435
#
# Optimal solution found (tolerance 1.00e-03)
# Best objective 1.071300000000e+04, best bound 1.071400000000e+04, gap 0.0093%
# Optimal solution found!
# Solution saved for k = 4 in /Users/Martijn/Downloads/KidneyExchangeOptimization/exact method/Solutions_branch_and_bound/Delorme_500_NDD_Weight_0_solution_k3.txt
# Results saved for k = 4, file: Delorme_500_NDD_Weight_0.txt
#
# Calculating cycles and paths for k = 5, file: Delorme_500_NDD_Weight_0.txt
# time.struct_time(tm_year=2024, tm_mon=10, tm_mday=14, tm_hour=16, tm_min=39, tm_sec=27, tm_wday=0, tm_yday=288, tm_isdst=1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 76
#      74 # Example usage
#      75 k_values = [4,5,6]
# ---> 76 process_files(input_directory, output_folder, k_values)
#
# Cell In[9], line 54, in process_files(directory, output_folder, k_values)
#      51 G = create_graph(data)
#      53 # Calculate cycles and paths for the current k
# ---> 54 cycles, paths = calculate_cycles_and_paths(G, data, k)
#      56 print("Cycles and paths processed. Starting optimization...")
#      57 print(time.localtime())
#
# Cell In[6], line 21, in calculate_cycles_and_paths(G, data, k)
#      19 for l in range(2, k+1):
#      20     for node in G.nodes:  # Iterate over all nodes in the graph
# ---> 21         for cyc in list(find_cycles(G, node, l)):  # Find all cycles starting at this node of length 'l'
#      22             cyc_success = 0
#      23             cyc_weight = 0
#
# Cell In[5], line 64, in find_cycles(G, u, n)
#      51 """
#      52 Finds all cycles of length n starting and ending at node u.
#      53
#    (...)
#      61                Each cycle is represented as a tuple of nodes.
#      62 """
#      63 # Find all paths of length n starting from node u
# ---> 64 paths = findPaths(G, u, n)
#      66 # Filter paths that form a cycle, meaning they end at u and visit u exactly twice
#      67 return [tuple(path) for path in paths if (path[-1] == u) and sum(x == u for x in path) == 2]
#
# Cell In[5], line 45, in findPaths(G, u, n)
#      42     return [[u]]
#      44 # Recursive case: explore neighbors of the current node and find paths of length n-1
# ---> 45 paths = [[u] + path for neighbor in G.neighbors(u) for path in findPaths(G, neighbor, n-1)]
#      47 return paths
#
# Cell In[5], line 45, in <listcomp>(.0)
#      42     return [[u]]
#      44 # Recursive case: explore neighbors of the current node and find paths of length n-1
# ---> 45 paths = [[u] + path for neighbor in G.neighbors(u) for path in findPaths(G, neighbor, n-1)]
#      47 return paths
#
# Cell In[5], line 45, in findPaths(G, u, n)
#      42     return [[u]]
#      44 # Recursive case: explore neighbors of the current node and find paths of length n-1
# ---> 45 paths = [[u] + path for neighbor in G.neighbors(u) for path in findPaths(G, neighbor, n-1)]
#      47 return paths
#
# Cell In[5], line 45, in <listcomp>(.0)
#      42     return [[u]]
#      44 # Recursive case: explore neighbors of the current node and find paths of length n-1
# ---> 45 paths = [[u] + path for neighbor in G.neighbors(u) for path in findPaths(G, neighbor, n-1)]
#      47 return paths
#
# KeyboardInterrupt:
